# %% [markdown]
# # Solutions
#
# 1. [Groupby Aggregation Basics](#1.-Groupby-Aggregation-Basics)
# 1. [Grouping and Aggregating with Multiple Columns](#2.-Grouping-and-Aggregating-with-Multiple-Columns)
# 1. [Grouping with Pivot Tables](#3.-Grouping-with-Pivot-Tables)
# 1. [Counting with Crosstabs](#4.-Counting-with-Crosstabs)

# %% [markdown]
# # 1. Groupby Aggregation Basics

# %%
import pandas as pd
nyc = pd.read_csv('../data/nyc_deaths.csv')
nyc.head()
# Out:
#    year      cause sex      race  deaths
# 0  2007  Accidents   F     Asian      32
# 1  2007  Accidents   F     Black      87
# 2  2007  Accidents   F  Hispanic      71
# 3  2007  Accidents   F     White     162
# 4  2007  Accidents   M     Asian      53

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">What year had the most deaths?</span>

# %%
year_deaths = nyc.groupby('year').agg({'deaths':'sum'})
year_deaths.idxmax()
# Out:
# deaths    2008
# dtype: int64

# %%
# one line
nyc.groupby('year').agg({'deaths':'sum'}).idxmax()
# Out:
# deaths    2008
# dtype: int64

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Find the total number of deaths by race and sort by most to least.</span>

# %%
nyc.groupby('race').agg({'deaths':'sum'}).sort_values('deaths', ascending=False)
# Out:
#           deaths
# race
# White     206487
# Black     111116
# Hispanic   74802
# Asian      26355
# Unknown     6238

# %% [markdown]
# ### Use the employee dataset for the remaining problems

# %%
emp = pd.read_csv('../data/employee.csv')
emp.head()
# Out:
#                    title                            dept   salary   race  \
# 0         POLICE OFFICER   Houston Police Department-HPD  45279.0  White
# 1      ENGINEER/OPERATOR   Houston Fire Department (HFD)  63166.0  White
# 2  SENIOR POLICE OFFICER   Houston Police Department-HPD  66614.0  Black
# 3               ENGINEER  Public Works & Engineering-PWE  71680.0  Asian
# 4              CARPENTER    Houston Airport System (HAS)  42390.0  White
#
#   gender   hire_date
# 0   Male  2015-02-03
# 1   Male  1982-02-08
# 2   Male  1984-11-26
# 3   Male  2012-03-26
# 4   Male  2013-11-04

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Find the maximum salary for each gender.</span>

# %%
emp.groupby('gender').agg({'salary':'max'})
# Out:
#           salary
# gender
# Female  178331.0
# Male    210588.0

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Find the median salary for each department.</span>

# %%
emp.groupby('dept').agg({'salary':'median'}).head()
# Out:
#                                 salary
# dept
# Health & Human Services        46717.0
# Houston Airport System (HAS)   41953.5
# Houston Fire Department (HFD)  61921.0
# Houston Police Department-HPD  61643.0
# Parks & Recreation             33634.0

# %% [markdown]
# ### Problem 5
# <span  style="color:green; font-size:16px">Find the average salary for each race. Return a DataFrame with the race as a column.</span>

# %%
emp.groupby('race').agg({'salary':'mean'}).reset_index()
# Out:
#               race        salary
# 0            Asian  60143.218391
# 1            Black  50366.588803
# 2         Hispanic  52533.456693
# 3  Native American  64562.142857
# 4            White  63834.575646

# %% [markdown]
# # 2. Grouping and Aggregating with Multiple Columns

# %%
emp = pd.read_csv('../data/employee.csv', parse_dates=['hire_date'])
emp['experience'] = 2016 - emp['hire_date'].dt.year
emp.head()
# Out:
#                    title                            dept   salary   race  \
# 0         POLICE OFFICER   Houston Police Department-HPD  45279.0  White
# 1      ENGINEER/OPERATOR   Houston Fire Department (HFD)  63166.0  White
# 2  SENIOR POLICE OFFICER   Houston Police Department-HPD  66614.0  Black
# 3               ENGINEER  Public Works & Engineering-PWE  71680.0  Asian
# 4              CARPENTER    Houston Airport System (HAS)  42390.0  White
#
#   gender  hire_date  experience
# 0   Male 2015-02-03           1
# 1   Male 1982-02-08          34
# 2   Male 1984-11-26          32
# 3   Male 2012-03-26           4
# 4   Male 2013-11-04           3

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">For each department and gender find the number of unique position titles, the total number of employees and the average salary. Make sure there is no multi-index for the index or columns.</span>

# %%
data = emp.groupby(['dept', 'gender']).agg({'title':['nunique','size'],
                                            'salary':'mean'}).reset_index()
data.columns = ['dept', 'gender', 'num unique positions', 'size', 'mean salary']
data.head(10)
# Out:
#                             dept  gender  num unique positions  size  \
# 0        Health & Human Services  Female                    47    82
# 1        Health & Human Services    Male                    22    26
# 2   Houston Airport System (HAS)  Female                    24    36
# 3   Houston Airport System (HAS)    Male                    37    70
# 4  Houston Fire Department (HFD)  Female                    13    21
# 5  Houston Fire Department (HFD)    Male                    26   363
# 6  Houston Police Department-HPD  Female                    38   155
# 7  Houston Police Department-HPD    Male                    27   483
# 8             Parks & Recreation  Female                    15    23
# 9             Parks & Recreation    Male                    20    51
#
#     mean salary
# 0  48661.961538
# 1  59240.000000
# 2  53174.194444
# 3  54358.171429
# 4  52853.047619
# 5  59930.564470
# 6  52219.925170
# 7  63032.841121
# 8  40361.055556
# 9  38396.243243

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">For each department, race and gender find the maximum years of experience and salary.</span>

# %%
emp.groupby(['dept','race','gender']).agg({'experience': 'max',
                                           'salary': 'max'}).reset_index().head(10)
# Out:
#                            dept             race  gender  experience    salary
# 0       Health & Human Services            Asian  Female          23   94149.0
# 1       Health & Human Services            Asian    Male          25   70864.0
# 2       Health & Human Services            Black  Female          34  103270.0
# 3       Health & Human Services            Black    Male          29  180416.0
# 4       Health & Human Services         Hispanic  Female          25   65589.0
# 5       Health & Human Services         Hispanic    Male          14   58406.0
# 6       Health & Human Services  Native American  Female          17   58855.0
# 7       Health & Human Services            White  Female          33  100791.0
# 8       Health & Human Services            White    Male           8  120799.0
# 9  Houston Airport System (HAS)            Asian  Female          23   32157.0

# %% [markdown]
# ## Use the college dataset for the rest of the problems

# %%
college = pd.read_csv('../data/college.csv')
college.head()
# Out:
#                                 instnm        city stabbr  hbcu  menonly  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    womenonly  relaffil  satvrmid  satmtmid  distanceonly         ...          \
# 0        0.0         0     424.0     420.0           0.0         ...
# 1        0.0         0     570.0     565.0           0.0         ...
# 2        0.0         1       NaN       NaN           1.0         ...
# 3        0.0         0     595.0     590.0           0.0         ...
# 4        0.0         0     425.0     430.0           0.0         ...
#
#    ugds_2mor  ugds_nra  ugds_unkn  pptug_ef  curroper  pctpell  pctfloan  \
# 0     0.0000    0.0059     0.0138    0.0656         1   0.7356    0.8284
# 1     0.0368    0.0179     0.0100    0.2607         1   0.3460    0.5214
# 2     0.0000    0.0000     0.2715    0.4536         1   0.6801    0.7795
# 3     0.0172    0.0332     0.0350    0.2146         1   0.3072    0.4596
# 4     0.0098    0.0243     0.0137    0.0892         1   0.7347    0.7554
#
#    ug25abv  md_earn_wne_p10  grad_debt_mdn_supp
# 0   0.1049            30300               33888
# 1   0.2422            39700             21941.5
# 2   0.8540            40100               23370
# 3   0.2640            45500               24097
# 4   0.1270            26600             33118.5
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Which city name appears the most frequently. Do this in two different ways. Do it once with and once without the `groupby` method?</span>

# %%
size = college.groupby('city').agg({'stabbr': 'size'})
size.head()
# Out:
#           stabbr
# city
# ARTESIA        1
# Aberdeen       3
# Abilene        5
# Abingdon       2
# Abington       1

# %%
size.sort_values('stabbr', ascending=False).head()
# Out:
#              stabbr
# city
# New York         87
# Chicago          78
# Houston          72
# Los Angeles      56
# Miami            51

# %% [markdown]
# Can also just `size` directly and sort the series.

# %%
college.groupby('city').size().sort_values(ascending=False).head()
# Out:
# city
# New York       87
# Chicago        78
# Houston        72
# Los Angeles    56
# Miami          51
# dtype: int64

# %% [markdown]
# ### Without groupby
# Just use **`value_counts`**! Much easier

# %%
college['city'].value_counts().head()
# Out:
# New York       87
# Chicago        78
# Houston        72
# Los Angeles    56
# Miami          51
# Name: city, dtype: int64

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Does the city **`Houston`** only appear in the state of **`Texas`**?</span>

# %% [markdown]
# NO! It also appears in Missouri.

# %%
filt = college['city'] == 'Houston'
college.loc[filt, 'stabbr'].unique()
# Out:
# array(['TX', 'MO'], dtype=object)

# %% [markdown]
# Can see exact counts

# %%
college.loc[filt, 'stabbr'].value_counts()
# Out:
# TX    71
# MO     1
# Name: stabbr, dtype: int64

# %% [markdown]
# You can use a groupby and find the number of unique states for each city. This is not very efficient.

# %%
city_unique_state = college.groupby('city').agg({'stabbr': 'nunique'})
city_unique_state.head()
# Out:
#           stabbr
# city
# ARTESIA        1
# Aberdeen       2
# Abilene        1
# Abingdon       1
# Abington       1

# %%
city_unique_state.loc['Houston']
# Out:
# stabbr    2
# Name: Houston, dtype: int64

# %% [markdown]
# ### Problem 5
# <span  style="color:green; font-size:16px">Find the maximum undergraduate population for each state?</span>

# %%
college.groupby('stabbr').agg({'ugds': 'max'}).head(10)
# Out:
#             ugds
# stabbr
# AK       12865.0
# AL       29851.0
# AR       21405.0
# AS        1276.0
# AZ      151558.0
# CA       44744.0
# CO       25873.0
# CT       18016.0
# DC       10433.0
# DE       18222.0

# %% [markdown]
# ### Problem 6
# <span  style="color:green; font-size:16px">Among colleges that have the largest undergrad population for each state, what is the difference between the most and least populous college?</span>

# %%
# from problem 8
largest_per_state = college.groupby('stabbr').agg({'ugds': 'max'})
largest_per_state.max() - largest_per_state.min()
# Out:
# ugds    150956.0
# dtype: float64

# %% [markdown]
# ### Problem 7: Advanced
# <span  style="color:green; font-size:16px">Find the name and population of the largest college per state.</span>

# %% [markdown]
# The following returns the index of the maximum value of population for each state.

# %%
max_indexes = college.groupby('stabbr').agg({'ugds': 'idxmax'})
max_indexes.head(10)
# Out:
#         ugds
# stabbr
# AK        60
# AL         5
# AR       137
# AS      4138
# AZ      7116
# CA      1299
# CO       574
# CT       641
# DC       701
# DE       691

# %% [markdown]
# For instance, the row with index label 60 as the maximum population for Alaska. Let's verify this by selecting the institution name and population of this specific row.

# %%
cols = ['instnm', 'ugds']
college.loc[60, cols]
# Out:
# instnm    University of Alaska Anchorage
# ugds                               12865
# Name: 60, dtype: object

# %% [markdown]
# Verify by selecting only Alaska colleges and getting the max value:

# %%
filt = college['stabbr'] == 'AK'
college.loc[filt, 'ugds'].max()
# Out:
# 12865.0

# %% [markdown]
# We need to get the index locations as a Series or a NumPy array to use with **`.loc`**. Currently **`max_indexes`** is a DataFrame.

# %%
locs = max_indexes['ugds']
locs.head()
# Out:
# stabbr
# AK      60
# AL       5
# AR     137
# AS    4138
# AZ    7116
# Name: ugds, dtype: int64

# %% [markdown]
# We can pass this Series to **`.loc`** which will select just those indexes, along with the columns we want.

# %%
cols = ['stabbr', 'instnm', 'ugds']
college.loc[locs, cols].head()
# Out:
#      stabbr                            instnm      ugds
# 60       AK    University of Alaska Anchorage   12865.0
# 5        AL         The University of Alabama   29851.0
# 137      AR            University of Arkansas   21405.0
# 4138     AS  American Samoa Community College    1276.0
# 7116     AZ     University of Phoenix-Arizona  151558.0

# %% [markdown]
# ### Alternative method if index is INSTNM

# %%
college_instm = college.set_index('instnm')
cols = ['stabbr', 'ugds']
college_instm = college_instm[cols]
college_instm.head()
# Out:
#                                     stabbr     ugds
# instnm
# Alabama A & M University                AL   4206.0
# University of Alabama at Birmingham     AL  11383.0
# Amridge University                      AL    291.0
# University of Alabama in Huntsville     AL   5451.0
# Alabama State University                AL   4811.0

# %%
# group by state and use idxmax
max_colleges = college_instm.groupby('stabbr').agg({'ugds': 'idxmax'})
max_colleges.head()
max_indexes = max_colleges['ugds']
college_instm.loc[max_indexes].head()
# Out:
#                                  stabbr      ugds
# instnm
# University of Alaska Anchorage       AK   12865.0
# The University of Alabama            AL   29851.0
# University of Arkansas               AR   21405.0
# American Samoa Community College     AS    1276.0
# University of Phoenix-Arizona        AZ  151558.0

# %% [markdown]
# ## Yet another way
# Use the **`first`** groupby method to return the first row of each group after sorting.

# %%
cols = ['stabbr', 'instnm', 'ugds']
college_trim = college[cols]

# sort by state then by population descending
college_trim_sort = college_trim.sort_values(['stabbr', 'ugds'], ascending=[True, False])


# group by state and take the first in the group
college_trim_sort.groupby('stabbr').first().head()
# Out:
#                                   instnm      ugds
# stabbr
# AK        University of Alaska Anchorage   12865.0
# AL             The University of Alabama   29851.0
# AR                University of Arkansas   21405.0
# AS      American Samoa Community College    1276.0
# AZ         University of Phoenix-Arizona  151558.0

# %% [markdown]
# ## Use `sort_values` with `drop_duplicates`
# We've done this in previous notebooks. No grouping.

# %%
college_trim.sort_values(['stabbr', 'ugds'], ascending=[True, False]) \
            .drop_duplicates(subset='stabbr').head(10)
# Out:
#      stabbr                            instnm      ugds
# 60       AK    University of Alaska Anchorage   12865.0
# 5        AL         The University of Alabama   29851.0
# 137      AR            University of Arkansas   21405.0
# 4138     AS  American Samoa Community College    1276.0
# 7116     AZ     University of Phoenix-Arizona  151558.0
# 1299     CA                Ashford University   44744.0
# 574      CO    University of Colorado Boulder   25873.0
# 641      CT         University of Connecticut   18016.0
# 701      DC      George Washington University   10433.0
# 691      DE            University of Delaware   18222.0

# %% [markdown]
# ### Problem 8
# <span  style="color:green; font-size:16px">Do distance only schools tend to have more or less student population than non-distance-only schools?</span>

# %%
# They have more
college.groupby('distanceonly').agg({'ugds': 'mean'})
# Out:
#                      ugds
# distanceonly
# 0.0           2334.648135
# 1.0           6245.743590

# %% [markdown]
# ### Problem 9
# <span  style="color:green; font-size:16px">Do distance only schools tend to be more or less religously affiliated than non-distance-only schools?</span>

# %%
# Less
college.groupby('distanceonly').agg({'relaffil': 'mean'})
# Out:
#               relaffil
# distanceonly
# 0.0           0.149635
# 1.0           0.050000

# %% [markdown]
# ### Problem 10
# <span  style="color:green; font-size:16px">What state has the lowest percentage of currently operating schools of those that have religious affiliation?</span>

# %%
filt = college['relaffil'] == 1
cr = college[filt]
rel_oper_mean = cr.groupby('stabbr').agg({'curroper': 'mean'})
rel_oper_mean.head()
# Out:
#         curroper
# stabbr
# AK      1.000000
# AL      0.916667
# AR      0.944444
# AZ      0.444444
# CA      0.585366

# %%
# Utah. Answer makes sense.
rel_oper_mean.sort_values('curroper').head()
# Out:
#         curroper
# stabbr
# UT      0.400000
# AZ      0.444444
# NV      0.500000
# CA      0.585366
# CT      0.647059

# %% [markdown]
# ### Problem 11
# <span  style="color:green; font-size:16px">Trim the **`college`** DataFrame to only the 'race' columns - those beginning with **`ugds_`**. Create a new column called **`ugds_other`** that is the sum of any race column that averages under 4% for the entire dataset.</span>

# %%
pd.options.display.max_columns = 100

# %%
college.head()
# Out:
#                                 instnm        city stabbr  hbcu  menonly  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    womenonly  relaffil  satvrmid  satmtmid  distanceonly     ugds  ugds_white  \
# 0        0.0         0     424.0     420.0           0.0   4206.0      0.0333
# 1        0.0         0     570.0     565.0           0.0  11383.0      0.5922
# 2        0.0         1       NaN       NaN           1.0    291.0      0.2990
# 3        0.0         0     595.0     590.0           0.0   5451.0      0.6988
# 4        0.0         0     425.0     430.0           0.0   4811.0      0.0158
#
#    ugds_black  ugds_hisp  ugds_asian  ugds_aian  ugds_nhpi  ugds_2mor  \
# 0      0.9353     0.0055      0.0019     0.0024     0.0019     0.0000
# 1      0.2600     0.0283      0.0518     0.0022     0.0007     0.0368
# 2      0.4192     0.0069      0.0034     0.0000     0.0000     0.0000
# 3      0.1255     0.0382      0.0376     0.0143     0.0002     0.0172
# 4      0.9208     0.0121      0.0019     0.0010     0.0006     0.0098
#
#    ugds_nra  ugds_unkn  pptug_ef  curroper  pctpell  pctfloan  ug25abv  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
# 4    0.0243     0.0137    0.0892         1   0.7347    0.7554   0.1270
#
#   md_earn_wne_p10 grad_debt_mdn_supp
# 0           30300              33888
# 1           39700            21941.5
# 2           40100              23370
# 3           45500              24097
# 4           26600            33118.5

# %%
# trim dataframe
df_race = college.loc[:, 'ugds_white':'ugds_unkn']

race_average = df_race.mean()

race_average
# Out:
# ugds_white    0.510207
# ugds_black    0.189997
# ugds_hisp     0.161635
# ugds_asian    0.033544
# ugds_aian     0.013813
# ugds_nhpi     0.004569
# ugds_2mor     0.023950
# ugds_nra      0.016086
# ugds_unkn     0.045181
# dtype: float64

# %%
# keep only those less than 4%
other_race = race_average[race_average < .04]

other_race
# Out:
# ugds_asian    0.033544
# ugds_aian     0.013813
# ugds_nhpi     0.004569
# ugds_2mor     0.023950
# ugds_nra      0.016086
# dtype: float64

# %%
# get the column names
race_columns = other_race.index

race_columns
# Out:
# Index(['ugds_asian', 'ugds_aian', 'ugds_nhpi', 'ugds_2mor', 'ugds_nra'], dtype='object')

# %%
# grab the columns and sum accross the rows
df_race['ugds_other'] = df_race[race_columns].sum(axis='columns')

# can drop the low percentage columns
df_race.drop(race_columns, axis=1).head(10)
# Out:
#    ugds_white  ugds_black  ugds_hisp  ugds_unkn  ugds_other
# 0      0.0333      0.9353     0.0055     0.0138      0.0121
# 1      0.5922      0.2600     0.0283     0.0100      0.1094
# 2      0.2990      0.4192     0.0069     0.2715      0.0034
# 3      0.6988      0.1255     0.0382     0.0350      0.1025
# 4      0.0158      0.9208     0.0121     0.0137      0.0376
# 5      0.7825      0.1119     0.0348     0.0026      0.0682
# 6      0.7255      0.2613     0.0044     0.0019      0.0069
# 7      0.7823      0.1200     0.0191     0.0334      0.0451
# 8      0.5328      0.3376     0.0074     0.0246      0.0975
# 9      0.8507      0.0704     0.0248     0.0140      0.0401

# %% [markdown]
# ### Problem 12
# <span  style="color:green; font-size:16px">Which top 5 historically black colleges that have the highest white percentage?</span>

# %%
filt = college['hbcu'] == 1
cols = ['instnm', 'ugds_white']
college.loc[filt, cols].sort_values('ugds_white', ascending=False).head()
# Out:
#                                            instnm  ugds_white
# 4021                      Bluefield State College      0.8437
# 17                Gadsden State Community College      0.6921
# 4050               West Virginia State University      0.5816
# 48                Shelton State Community College      0.5613
# 55    H Councill Trenholm State Community College      0.3951

# %% [markdown]
# # 3. Grouping with Pivot Tables

# %%
import pandas as pd
pd.options.display.max_columns = 100
flights = pd.read_csv('../data/flights.csv')
flights.head()
# Out:
#    year  month  day  day_of_week airline  flight_number tail_number  \
# 0  2015      1    1            4      WN           1908      N8324A
# 1  2015      1    1            4      UA            581      N448UA
# 2  2015      1    1            4      MQ           2851      N645MQ
# 3  2015      1    1            4      AA            383      N3EUAA
# 4  2015      1    1            4      WN           3047      N560WN
#
#   origin_airport destination_airport  scheduled_departure  departure_time  \
# 0            LAX                 SLC                 1625          1723.0
# 1            DEN                 IAD                  823           830.0
# 2            DFW                 VPS                 1305          1341.0
# 3            DFW                 DCA                 1555          1602.0
# 4            LAX                 MCI                 1720          1808.0
#
#    departure_delay  taxi_out  wheels_off  scheduled_time  elapsed_time  \
# 0             58.0      10.0      1733.0           100.0         107.0
# 1              7.0      11.0       841.0           190.0         170.0
# 2             36.0      18.0      1359.0           108.0         107.0
# 3              7.0      13.0      1615.0           160.0         146.0
# 4             48.0       6.0      1814.0           185.0         176.0
#
#    air_time  distance  wheels_on  taxi_in  scheduled_arrival  arrival_time  \
# 0      94.0       590     2007.0      3.0               1905        2010.0
# 1     154.0      1452     1315.0      5.0               1333        1320.0
# 2      85.0       641     1524.0      4.0               1453        1528.0
# 3     126.0      1192     1921.0      7.0               1935        1928.0
# 4     166.0      1363     2300.0      4.0               2225        2304.0
#
#    arrival_delay  diverted  cancelled cancellation_reason  air_system_delay  \
# 0           65.0         0          0                 NaN              31.0
# 1          -13.0         0          0                 NaN               NaN
# 2           35.0         0          0                 NaN               0.0
# 3           -7.0         0          0                 NaN               NaN
# 4           39.0         0          0                 NaN               0.0
#
#    security_delay  airline_delay  late_aircraft_delay  weather_delay
# 0             0.0            0.0                 34.0            0.0
# 1             NaN            NaN                  NaN            NaN
# 2             0.0           35.0                  0.0            0.0
# 3             NaN            NaN                  NaN            NaN
# 4             0.0           17.0                 22.0            0.0

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">What is the average departure delay for each day of the week for each airline? Highlight the worst day of the week for each airline.</span>

# %%
avg_delay = flights.pivot_table(index='airline', columns='day_of_week', 
                                values='departure_delay').round(1)
avg_delay.style.highlight_max(axis='columns')
# Out:
# <style  type="text/css" >
#     #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col0 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col3 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col3 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col3 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col0 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col2 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col4 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow6_col1 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow7_col4 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow8_col6 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow9_col6 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow10_col0 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow11_col0 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow12_col6 {
#             background-color:  yellow;
#         }    #T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow13_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68c" >
# <thead>    <tr>
#         <th class="index_name level0" >day_of_week</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#     </tr>    <tr>
#         <th class="index_name level0" >airline</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68clevel0_row0" class="row_heading level0 row0" >AA</th>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col0" class="data row0 col0" >14.4</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col1" class="data row0 col1" >9.1</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col2" class="data row0 col2" >9.3</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col3" class="data row0 col3" >11.8</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col4" class="data row0 col4" >11.3</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col5" class="data row0 col5" >12.9</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow0_col6" class="data row0 col6" >10.5</td>
#     </tr>    <tr>
#         <th id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68clevel0_row1" class="row_heading level0 row1" >AS</th>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col0" class="data row1 col0" >1.7</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col1" class="data row1 col1" >-0.9</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col2" class="data row1 col2" >-2.4</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col3" class="data row1 col3" >7.5</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col4" class="data row1 col4" >2.2</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col5" class="data row1 col5" >1.8</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow1_col6" class="data row1 col6" >2.8</td>
#     </tr>    <tr>
#         <th id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68clevel0_row2" class="row_heading level0 row2" >B6</th>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col0" class="data row2 col0" >13.7</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col1" class="data row2 col1" >14.7</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col2" class="data row2 col2" >11</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col3" class="data row2 col3" >20.7</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col4" class="data row2 col4" >11.2</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col5" class="data row2 col5" >10.8</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow2_col6" class="data row2 col6" >16.5</td>
#     </tr>    <tr>
#         <th id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68clevel0_row3" class="row_heading level0 row3" >DL</th>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col0" class="data row3 col0" >7.7</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col1" class="data row3 col1" >7.8</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col2" class="data row3 col2" >7.9</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col3" class="data row3 col3" >8.8</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col4" class="data row3 col4" >6.9</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col5" class="data row3 col5" >5.9</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow3_col6" class="data row3 col6" >5.3</td>
#     </tr>    <tr>
#         <th id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68clevel0_row4" class="row_heading level0 row4" >EV</th>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col0" class="data row4 col0" >12.5</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col1" class="data row4 col1" >7.9</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col2" class="data row4 col2" >9.3</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col3" class="data row4 col3" >9.5</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col4" class="data row4 col4" >7.8</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col5" class="data row4 col5" >6.5</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow4_col6" class="data row4 col6" >9.7</td>
#     </tr>    <tr>
#         <th id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68clevel0_row5" class="row_heading level0 row5" >F9</th>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col0" class="data row5 col0" >13.2</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col1" class="data row5 col1" >15.3</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col2" class="data row5 col2" >16.3</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col3" class="data row5 col3" >10.7</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col4" class="data row5 col4" >16.3</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col5" class="data row5 col5" >12.5</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow5_col6" class="data row5 col6" >15.6</td>
#     </tr>    <tr>
#         <th id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68clevel0_row6" class="row_heading level0 row6" >HA</th>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow6_col0" class="data row6 col0" >7.3</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow6_col1" class="data row6 col1" >15.2</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow6_col2" class="data row6 col2" >0.8</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow6_col3" class="data row6 col3" >-1.7</td>
#         <td id="T_e123ec58_d4d0_11e8_be3d_b8e85647e68crow6_col4" class="data row6 col4" >-1.7</td>
#         <td id="

# %% [markdown]
# You can highlight min and max by chaining style methods.

# %%
avg_delay.style.highlight_max(axis='columns') \
         .highlight_min(axis='columns', color='lightblue')
# Out:
# <style  type="text/css" >
#     #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col1 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col2 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col5 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col3 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col6 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow4_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow4_col5 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow5_col2 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow5_col3 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow5_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow6_col5 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow7_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow7_col5 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow8_col2 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow8_col6 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow9_col3 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow9_col6 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow10_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow10_col5 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow11_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow11_col1 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow12_col2 {
#             : ;
#             background-color:  lightblue;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow12_col6 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow13_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_e1380308_d4d0_11e8_bd37_b8e85647e68crow13_col5 {
#             : ;
#             background-color:  lightblue;
#         }</style>
# <table id="T_e1380308_d4d0_11e8_bd37_b8e85647e68c" >
# <thead>    <tr>
#         <th class="index_name level0" >day_of_week</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#     </tr>    <tr>
#         <th class="index_name level0" >airline</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e1380308_d4d0_11e8_bd37_b8e85647e68clevel0_row0" class="row_heading level0 row0" >AA</th>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col0" class="data row0 col0" >14.4</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col1" class="data row0 col1" >9.1</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col2" class="data row0 col2" >9.3</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col3" class="data row0 col3" >11.8</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col4" class="data row0 col4" >11.3</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col5" class="data row0 col5" >12.9</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow0_col6" class="data row0 col6" >10.5</td>
#     </tr>    <tr>
#         <th id="T_e1380308_d4d0_11e8_bd37_b8e85647e68clevel0_row1" class="row_heading level0 row1" >AS</th>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col0" class="data row1 col0" >1.7</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col1" class="data row1 col1" >-0.9</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col2" class="data row1 col2" >-2.4</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col3" class="data row1 col3" >7.5</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col4" class="data row1 col4" >2.2</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col5" class="data row1 col5" >1.8</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow1_col6" class="data row1 col6" >2.8</td>
#     </tr>    <tr>
#         <th id="T_e1380308_d4d0_11e8_bd37_b8e85647e68clevel0_row2" class="row_heading level0 row2" >B6</th>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col0" class="data row2 col0" >13.7</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col1" class="data row2 col1" >14.7</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col2" class="data row2 col2" >11</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col3" class="data row2 col3" >20.7</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col4" class="data row2 col4" >11.2</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col5" class="data row2 col5" >10.8</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow2_col6" class="data row2 col6" >16.5</td>
#     </tr>    <tr>
#         <th id="T_e1380308_d4d0_11e8_bd37_b8e85647e68clevel0_row3" class="row_heading level0 row3" >DL</th>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col0" class="data row3 col0" >7.7</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col1" class="data row3 col1" >7.8</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col2" class="data row3 col2" >7.9</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col3" class="data row3 col3" >8.8</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col4" class="data row3 col4" >6.9</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col5" class="data row3 col5" >5.9</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow3_col6" class="data row3 col6" >5.3</td>
#     </tr>    <tr>
#         <th id="T_e1380308_d4d0_11e8_bd37_b8e85647e68clevel0_row4" class="row_heading level0 row4" >EV</th>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow4_col0" class="data row4 col0" >12.5</td>
#         <td id="T_e1380308_d4d0_11e8_bd37_b8e85647e68crow4_col1" class="data row4 col1" >7.9</td>
#         <td i

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Find the airline and origin airport that has the most canceled flights. Highlight the maximum value of the table. Read the docs to see how it's done.</span>

# %%
airline_cancel = flights.pivot_table(index='airline', columns='origin_airport', 
                                     values='cancelled', aggfunc='sum', fill_value=0)
airline_cancel.style.highlight_max(axis=None)
# Out:
# <style  type="text/css" >
#     #T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_e1473436_d4d0_11e8_952c_b8e85647e68c" >
# <thead>    <tr>
#         <th class="index_name level0" >origin_airport</th>
#         <th class="col_heading level0 col0" >ATL</th>
#         <th class="col_heading level0 col1" >DEN</th>
#         <th class="col_heading level0 col2" >DFW</th>
#         <th class="col_heading level0 col3" >IAH</th>
#         <th class="col_heading level0 col4" >LAS</th>
#         <th class="col_heading level0 col5" >LAX</th>
#         <th class="col_heading level0 col6" >MSP</th>
#         <th class="col_heading level0 col7" >ORD</th>
#         <th class="col_heading level0 col8" >PHX</th>
#         <th class="col_heading level0 col9" >SFO</th>
#     </tr>    <tr>
#         <th class="index_name level0" >airline</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e1473436_d4d0_11e8_952c_b8e85647e68clevel0_row0" class="row_heading level0 row0" >AA</th>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col0" class="data row0 col0" >3</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col1" class="data row0 col1" >4</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col2" class="data row0 col2" >86</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col3" class="data row0 col3" >3</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col4" class="data row0 col4" >3</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col5" class="data row0 col5" >11</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col6" class="data row0 col6" >3</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col7" class="data row0 col7" >35</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col8" class="data row0 col8" >4</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow0_col9" class="data row0 col9" >2</td>
#     </tr>    <tr>
#         <th id="T_e1473436_d4d0_11e8_952c_b8e85647e68clevel0_row1" class="row_heading level0 row1" >AS</th>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col0" class="data row1 col0" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col1" class="data row1 col1" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col2" class="data row1 col2" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col3" class="data row1 col3" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col4" class="data row1 col4" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col5" class="data row1 col5" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col6" class="data row1 col6" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col7" class="data row1 col7" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col8" class="data row1 col8" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow1_col9" class="data row1 col9" >0</td>
#     </tr>    <tr>
#         <th id="T_e1473436_d4d0_11e8_952c_b8e85647e68clevel0_row2" class="row_heading level0 row2" >B6</th>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col0" class="data row2 col0" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col1" class="data row2 col1" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col2" class="data row2 col2" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col3" class="data row2 col3" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col4" class="data row2 col4" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col5" class="data row2 col5" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col6" class="data row2 col6" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col7" class="data row2 col7" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col8" class="data row2 col8" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow2_col9" class="data row2 col9" >1</td>
#     </tr>    <tr>
#         <th id="T_e1473436_d4d0_11e8_952c_b8e85647e68clevel0_row3" class="row_heading level0 row3" >DL</th>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col0" class="data row3 col0" >28</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col1" class="data row3 col1" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col2" class="data row3 col2" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col3" class="data row3 col3" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col4" class="data row3 col4" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col5" class="data row3 col5" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col6" class="data row3 col6" >4</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col7" class="data row3 col7" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col8" class="data row3 col8" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow3_col9" class="data row3 col9" >2</td>
#     </tr>    <tr>
#         <th id="T_e1473436_d4d0_11e8_952c_b8e85647e68clevel0_row4" class="row_heading level0 row4" >EV</th>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col0" class="data row4 col0" >18</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col1" class="data row4 col1" >6</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col2" class="data row4 col2" >27</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col3" class="data row4 col3" >36</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col4" class="data row4 col4" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col5" class="data row4 col5" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col6" class="data row4 col6" >6</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col7" class="data row4 col7" >53</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col8" class="data row4 col8" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow4_col9" class="data row4 col9" >0</td>
#     </tr>    <tr>
#         <th id="T_e1473436_d4d0_11e8_952c_b8e85647e68clevel0_row5" class="row_heading level0 row5" >F9</th>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col0" class="data row5 col0" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col1" class="data row5 col1" >2</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col2" class="data row5 col2" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col3" class="data row5 col3" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col4" class="data row5 col4" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col5" class="data row5 col5" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col6" class="data row5 col6" >1</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col7" class="data row5 col7" >4</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col8" class="data row5 col8" >0</td>
#         <td id="T_e1473436_d4d0_11e8_952c_b8e85647e68crow5_col9" class="data row5 col9" >0</td>
#     </tr>    <tr>
#         <th id="T_e1473436_d4d0_11e8_952c_b8e85647e68clevel0_row6" class="row_heading level0 row6" >HA</th>
#         <td id="T_e1473436

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Find the total distance flown for each airline for each month. Can you use the style `format` method to put commas in the numbers so that they are easier to read?</span>

# %%
total_dist = flights.pivot_table(index='airline', columns='month', 
                                 values='distance', aggfunc='sum')

# %%
# we also highlight the max month for each airline
total_dist.style.format('{:,.0f}').highlight_max(axis='columns')
# Out:
# <style  type="text/css" >
#     #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col6 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col4 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col10 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col7 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow4_col2 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow5_col4 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow6_col0 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow7_col0 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow8_col9 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow9_col4 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow10_col6 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow11_col5 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow12_col8 {
#             background-color:  yellow;
#         }    #T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow13_col6 {
#             background-color:  yellow;
#         }</style>
# <table id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68c" >
# <thead>    <tr>
#         <th class="index_name level0" >month</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#         <th class="col_heading level0 col5" >6</th>
#         <th class="col_heading level0 col6" >7</th>
#         <th class="col_heading level0 col7" >8</th>
#         <th class="col_heading level0 col8" >9</th>
#         <th class="col_heading level0 col9" >11</th>
#         <th class="col_heading level0 col10" >12</th>
#     </tr>    <tr>
#         <th class="index_name level0" >airline</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68clevel0_row0" class="row_heading level0 row0" >AA</th>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col0" class="data row0 col0" >728,748</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col1" class="data row0 col1" >678,434</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col2" class="data row0 col2" >773,487</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col3" class="data row0 col3" >775,426</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col4" class="data row0 col4" >728,602</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col5" class="data row0 col5" >840,028</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col6" class="data row0 col6" >1,175,729</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col7" class="data row0 col7" >1,124,517</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col8" class="data row0 col8" >1,027,703</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col9" class="data row0 col9" >1,001,409</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow0_col10" class="data row0 col10" >1,063,613</td>
#     </tr>    <tr>
#         <th id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68clevel0_row1" class="row_heading level0 row1" >AS</th>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col0" class="data row1 col0" >68,255</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col1" class="data row1 col1" >63,920</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col2" class="data row1 col2" >66,004</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col3" class="data row1 col3" >84,302</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col4" class="data row1 col4" >88,380</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col5" class="data row1 col5" >87,994</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col6" class="data row1 col6" >86,077</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col7" class="data row1 col7" >62,637</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col8" class="data row1 col8" >69,188</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col9" class="data row1 col9" >67,073</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow1_col10" class="data row1 col10" >74,769</td>
#     </tr>    <tr>
#         <th id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68clevel0_row2" class="row_heading level0 row2" >B6</th>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col0" class="data row2 col0" >78,150</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col1" class="data row2 col1" >79,298</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col2" class="data row2 col2" >59,978</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col3" class="data row2 col3" >81,902</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col4" class="data row2 col4" >98,000</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col5" class="data row2 col5" >105,232</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col6" class="data row2 col6" >85,799</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col7" class="data row2 col7" >90,605</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col8" class="data row2 col8" >91,253</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col9" class="data row2 col9" >86,255</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow2_col10" class="data row2 col10" >105,660</td>
#     </tr>    <tr>
#         <th id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68clevel0_row3" class="row_heading level0 row3" >DL</th>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col0" class="data row3 col0" >733,393</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col1" class="data row3 col1" >654,574</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col2" class="data row3 col2" >905,960</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col3" class="data row3 col3" >853,458</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col4" class="data row3 col4" >878,038</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col5" class="data row3 col5" >877,052</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col6" class="data row3 col6" >904,442</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col7" class="data row3 col7" >987,795</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col8" class="data row3 col8" >800,168</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col9" class="data row3 col9" >775,772</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow3_col10" class="data row3 col10" >814,568</td>
#     </tr>    <tr>
#         <th id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68clevel0_row4" class="row_heading level0 row4" >EV</th>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow4_col0" class="data row4 col0" >261,396</td>
#         <td id="T_e157ce2c_d4d0_11e8_a7a2_b8e85647e68crow4_col1" class="

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Use the employee dataset for this problem. You can create pivot tables with multiple columns in the index or the columns by using a list. Create a pivot table with the department as the index and the race and gender as the columns. Calculate the median salary for these cross sections.</span>

# %%
emp = pd.read_csv('../data/employee.csv')
emp.pivot_table(index='dept', columns=['race', 'gender'], 
                values='salary', aggfunc='median').round(-3).style.format('{:,.0f}')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68c" >
# <thead>    <tr>
#         <th class="index_name level0" >race</th>
#         <th class="col_heading level0 col0" colspan=2>Asian</th>
#         <th class="col_heading level0 col2" colspan=2>Black</th>
#         <th class="col_heading level0 col4" colspan=2>Hispanic</th>
#         <th class="col_heading level0 col6" colspan=2>Native American</th>
#         <th class="col_heading level0 col8" colspan=2>White</th>
#     </tr>    <tr>
#         <th class="index_name level1" >gender</th>
#         <th class="col_heading level1 col0" >Female</th>
#         <th class="col_heading level1 col1" >Male</th>
#         <th class="col_heading level1 col2" >Female</th>
#         <th class="col_heading level1 col3" >Male</th>
#         <th class="col_heading level1 col4" >Female</th>
#         <th class="col_heading level1 col5" >Male</th>
#         <th class="col_heading level1 col6" >Female</th>
#         <th class="col_heading level1 col7" >Male</th>
#         <th class="col_heading level1 col8" >Female</th>
#         <th class="col_heading level1 col9" >Male</th>
#     </tr>    <tr>
#         <th class="index_name level0" >dept</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68clevel0_row0" class="row_heading level0 row0" >Health & Human Services</th>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col0" class="data row0 col0" >50,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col1" class="data row0 col1" >53,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col2" class="data row0 col2" >47,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col3" class="data row0 col3" >55,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col4" class="data row0 col4" >33,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col5" class="data row0 col5" >34,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col6" class="data row0 col6" >54,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col7" class="data row0 col7" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col8" class="data row0 col8" >51,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow0_col9" class="data row0 col9" >56,000</td>
#     </tr>    <tr>
#         <th id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68clevel0_row1" class="row_heading level0 row1" >Houston Airport System (HAS)</th>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col0" class="data row1 col0" >29,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col1" class="data row1 col1" >50,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col2" class="data row1 col2" >37,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col3" class="data row1 col3" >42,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col4" class="data row1 col4" >31,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col5" class="data row1 col5" >40,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col6" class="data row1 col6" >68,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col7" class="data row1 col7" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col8" class="data row1 col8" >70,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow1_col9" class="data row1 col9" >56,000</td>
#     </tr>    <tr>
#         <th id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68clevel0_row2" class="row_heading level0 row2" >Houston Fire Department (HFD)</th>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col0" class="data row2 col0" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col1" class="data row2 col1" >44,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col2" class="data row2 col2" >52,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col3" class="data row2 col3" >58,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col4" class="data row2 col4" >47,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col5" class="data row2 col5" >55,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col6" class="data row2 col6" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col7" class="data row2 col7" >78,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col8" class="data row2 col8" >51,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow2_col9" class="data row2 col9" >63,000</td>
#     </tr>    <tr>
#         <th id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68clevel0_row3" class="row_heading level0 row3" >Houston Police Department-HPD</th>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col0" class="data row3 col0" >53,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col1" class="data row3 col1" >55,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col2" class="data row3 col2" >48,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col3" class="data row3 col3" >67,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col4" class="data row3 col4" >48,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col5" class="data row3 col5" >62,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col6" class="data row3 col6" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col7" class="data row3 col7" >60,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col8" class="data row3 col8" >67,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow3_col9" class="data row3 col9" >67,000</td>
#     </tr>    <tr>
#         <th id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68clevel0_row4" class="row_heading level0 row4" >Parks & Recreation</th>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col0" class="data row4 col0" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col1" class="data row4 col1" >49,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col2" class="data row4 col2" >31,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col3" class="data row4 col3" >34,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col4" class="data row4 col4" >43,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col5" class="data row4 col5" >30,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col6" class="data row4 col6" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col7" class="data row4 col7" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col8" class="data row4 col8" >nan</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow4_col9" class="data row4 col9" >37,000</td>
#     </tr>    <tr>
#         <th id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68clevel0_row5" class="row_heading level0 row5" >Public Works & Engineering-PWE</th>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow5_col0" class="data row5 col0" >86,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow5_col1" class="data row5 col1" >56,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow5_col2" class="data row5 col2" >37,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9e1a_b8e85647e68crow5_col3" class="data row5 col3" >39,000</td>
#         <td id="T_e15ce826_d4d0_11e8_9

# %% [markdown]
# # 4. Counting with Crosstabs

# %%
import pandas as pd
pd.options.display.max_columns = 100
pd.options.display.max_colwidth = 200
mh = pd.read_csv('../data/mental_health.csv')
mh.head()
# Out:
#              timestamp  age  gender         country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees remote_work  \
# 0             No       Yes          Often            6-25          No
# 1             No        No         Rarely  More than 1000          No
# 2             No        No         Rarely            6-25          No
# 3            Yes       Yes          Often          26-100          No
# 4             No        No          Never         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# 0          Yes         Yes     Not sure               No         Yes
# 1           No  Don't know           No       Don't know  Don't know
# 2          Yes          No           No               No          No
# 3          Yes          No          Yes               No          No
# 4          Yes         Yes           No       Don't know  Don't know
#
#     anonymity               leave mental_health_consequence  \
# 0         Yes       Somewhat easy                        No
# 1  Don't know          Don't know                     Maybe
# 2  Don't know  Somewhat difficult                        No
# 3          No  Somewhat difficult                       Yes
# 4  Don't know          Don't know                        No
#
#   phys_health_consequence     coworkers supervisor mental_health_interview  \
# 0                      No  Some of them        Yes                      No
# 1                      No            No         No                      No
# 2                      No           Yes        Yes                     Yes
# 3                     Yes  Some of them         No                   Maybe
# 4                      No  Some of them        Yes                     Yes
#
#   phys_health_interview mental_vs_physical obs_consequence comments
# 0                 Maybe                Yes              No      NaN
# 1                    No         Don't know              No      NaN
# 2                   Yes                 No              No      NaN
# 3                 Maybe                 No             Yes      NaN
# 4                   Yes         Don't know              No      NaN

# %%
pd.read_csv('../data/mental_health_dd.csv')
# Out:
#                   Column Name  \
# 0                   timestamp
# 1                         age
# 2                      gender
# 3                     country
# 4                       state
# 5               self_employed
# 6              family_history
# 7                   treatment
# 8              work_interfere
# 9                no_employees
# 10                remote_work
# 11               tech_company
# 12                   benefits
# 13               care_options
# 14           wellness_program
# 15                  seek_help
# 16                  anonymity
# 17                      leave
# 18  mental_health_consequence
# 19    phys_health_consequence
# 20                  coworkers
# 21                 supervisor
# 22    mental_health_interview
# 23      phys_health_interview
# 24         mental_vs_physical
# 25            obs_consequence
# 26                   comments
#
#                                                                                                              Description
# 0                                                                                          Time the survey was submitted
# 1                                                                                                         Respondent age
# 2                                                                                                      Respondent gender
# 3                                                                                                     Respondent country
# 4                                             If you live in the United States, which state or territory do you live in?
# 5                                                                                                 Are you self-employed?
# 6                                                                        Do you have a family history of mental illness?
# 7                                                               Have you sought treatment for a mental health condition?
# 8                                  If you have a mental health condition, do you feel that it interferes with your work?
# 9                                                             How many employees does your company or organization have?
# 10                                                 Do you work remotely (outside of an office) at least 50% of the time?
# 11                                                               Is your employer primarily a tech company/organization?
# 12                                                                    Does your employer provide mental health benefits?
# 13                                                Do you know the options for mental health care your employer provides?
# 14                               Has your employer ever discussed mental health as part of an employee wellness program?
# 15                   Does your employer provide resources to learn more about mental health issues and how to seek help?
# 16  Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
# 17                                           How easy is it for you to take medical leave for a mental health condition?
# 18               Do you think that discussing a mental health issue with your employer would have negative consequences?
# 19             Do you think that discussing a physical health issue with your employer would have negative consequences?
# 20                                            Would you be willing to discuss a mental health issue with your coworkers?
# 21                                 Would you be willing to discuss a mental health issue with your direct supervisor(s)?
# 22                                   Would you bring up a mental health issue with a potential employer in an interview?
# 23                                 Would you bring up a physical health issue with a potential employer in an interview?
# 24                                   Do you feel that your employer takes mental health as seriously as physical health?
# 25    Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
# 26                                                                                      Any additional notes or comments

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">Do people with a family history of mental illness seek treatment more often than those who do not?</span>

# %%
pd.crosstab(index=mh['family_history'], columns=mh['treatment'])
# Out:
# treatment        No  Yes
# family_history
# No              427  255
# Yes             116  343

# %%
pd.crosstab(index=mh['family_history'], columns=mh['treatment'], normalize='index').round(2)
# Out:
# treatment         No   Yes
# family_history
# No              0.63  0.37
# Yes             0.25  0.75

# %% [markdown]
# Yes, there is a large difference. 75% of people with a family history seek treatment vs 37% for those who have not.

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Find the total number and ratio of employees that seek treatment for companies that provide health benefits vs those that do not.</span>

# %%
pd.crosstab(index=mh['benefits'], columns=mh['treatment'])
# Out:
# treatment    No  Yes
# benefits
# Don't know  231  141
# No          146  158
# Yes         166  299

# %%
pd.crosstab(index=mh['benefits'], columns=mh['treatment'], normalize='index').round(2)
# Out:
# treatment     No   Yes
# benefits
# Don't know  0.62  0.38
# No          0.48  0.52
# Yes         0.36  0.64

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">You can provide a list of multiple columns to both the `index` and `columns` parameters of the `crosstab` function. Put country and number of employees in the index and benefits and treatment in the columns. It's probably easier to make separate list variables first.</span>

# %%
index = [mh['country'], mh['no_employees']]
columns = [mh['benefits'], mh['treatment']]
pd.crosstab(index=index, columns=columns)
# Out:
# benefits                      Don't know      No     Yes
# treatment                             No Yes  No Yes  No Yes
# country        no_employees
# Australia      1-5                     1   0   1   1   0   0
#                100-500                 1   0   1   2   0   2
#                26-100                  0   0   1   3   0   0
#                500-1000                1   0   0   0   0   0
#                6-25                    0   1   0   3   0   0
#                More than 1000          1   0   0   0   1   1
# Canada         1-5                     1   0   5   5   0   0
#                100-500                 2   3   0   0   2   4
#                26-100                  4   4   3   1   3   3
#                500-1000                0   0   0   0   0   1
#                6-25                    4   2   6   1   3   5
#                More than 1000          0   2   0   0   2   6
# France         100-500                 1   0   1   0   0   0
#                26-100                  0   0   3   1   0   0
#                500-1000                1   0   0   0   1   0
#                6-25                    1   0   3   0   0   1
# Germany        1-5                     0   0   3   3   0   1
#                100-500                 1   3   1   0   0   0
#                26-100                  2   4   4   3   1   0
#                500-1000                1   0   0   0   1   0
#                6-25                    5   1   3   3   0   2
#                More than 1000          2   1   0   0   0   0
# Ireland        1-5                     1   0   5   4   0   0
#                100-500                 1   0   0   1   0   0
#                26-100                  0   1   2   3   0   0
#                500-1000                0   0   0   0   0   1
#                6-25                    0   0   1   2   0   0
#                More than 1000          2   0   1   0   1   1
# Netherlands    1-5                     2   2   1   2   0   1
#                100-500                 1   0   0   0   1   1
#                26-100                  1   0   2   1   0   0
#                500-1000                1   0   0   0   0   0
#                6-25                    1   1   7   1   0   0
#                More than 1000          0   0   0   0   1   0
# United Kingdom 1-5                     6   3   8  13   0   1
#                100-500                 5   6   2   4   2   1
#                26-100                 12   5   7  11   3   2
#                500-1000                2   3   1   0   1   0
#                6-25                   11   8  23  14   1   1
#                More than 1000          5   6   3   7   0   8
# United States  1-5                    11   4  16  31   3  11
#                100-500                22  15   3   8  23  42
#                26-100                 42  27   7   7  21  66
#                500-1000                9   1   1   1  10  20
#                6-25                   32  23  16  20  17  26
#                More than 1000         35  15   5   2  68  91
