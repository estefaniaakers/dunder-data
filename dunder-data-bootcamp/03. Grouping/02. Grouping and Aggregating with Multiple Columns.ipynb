# %% [markdown]
# # 2. Grouping and Aggregating with Multiple Columns
#
# ### Objectives
#
# + Use multiple grouping columns
# + Aggregate multiple columns
# + Use multiple aggregating functions
# + Rename columns after grouping
# + Be aware of alternate syntax for grouping
#
# ### Overview
# In this notebook we will learn how to form groups using more than one column. We will also aggregate more than one column as well as learn how to apply more than one aggregation function to each group.

# %% [markdown]
# ## Adding Years of Experience to City of Houston Data
# Before we get started with grouping and aggregating multiple columns, let's read in the City of Houston employee dataset and append a column for the years of experience.

# %%
import pandas as pd
emp = pd.read_csv('../data/employee.csv', parse_dates=['hire_date'])
emp.head()
# Out:
#                    title                            dept   salary   race  \
# 0         POLICE OFFICER   Houston Police Department-HPD  45279.0  White
# 1      ENGINEER/OPERATOR   Houston Fire Department (HFD)  63166.0  White
# 2  SENIOR POLICE OFFICER   Houston Police Department-HPD  66614.0  Black
# 3               ENGINEER  Public Works & Engineering-PWE  71680.0  Asian
# 4              CARPENTER    Houston Airport System (HAS)  42390.0  White
#
#   gender  hire_date
# 0   Male 2015-02-03
# 1   Male 1982-02-08
# 2   Male 1984-11-26
# 3   Male 2012-03-26
# 4   Male 2013-11-04

# %% [markdown]
# ### Calculate years of experience from hire date
# The data was pulled on December 1, 2016. Let's use the **`dt`** accessor with the **`year`** attribute to get the year that each employee was hired. We can subtract this year from 2016 to approximate the years of experience and assign it as a new column.

# %%
emp['experience'] = 2016 - emp['hire_date'].dt.year

# %% [markdown]
# ### Take a peak at distribution of experience
# Use the **`value_counts`** to get a quick understanding of how experience is distributed.

# %%
emp['experience'].value_counts(normalize=True).head(10)
# Out:
# 1     0.069570
# 9     0.053237
# 2     0.047792
# 8     0.047792
# 3     0.044162
# 10    0.041742
# 23    0.039322
# 0     0.038717
# 13    0.036298
# 7     0.036298
# Name: experience, dtype: float64

# %%
emp.head()
# Out:
#                    title                            dept   salary   race  \
# 0         POLICE OFFICER   Houston Police Department-HPD  45279.0  White
# 1      ENGINEER/OPERATOR   Houston Fire Department (HFD)  63166.0  White
# 2  SENIOR POLICE OFFICER   Houston Police Department-HPD  66614.0  Black
# 3               ENGINEER  Public Works & Engineering-PWE  71680.0  Asian
# 4              CARPENTER    Houston Airport System (HAS)  42390.0  White
#
#   gender  hire_date  experience
# 0   Male 2015-02-03           1
# 1   Male 1982-02-08          34
# 2   Male 1984-11-26          32
# 3   Male 2012-03-26           4
# 4   Male 2013-11-04           3

# %% [markdown]
# ## Review grouping and aggregating with a single column
# In the previous notebook, we had a single grouping column, aggregating column, and aggregating function. The following syntax was used as a guide:
#
# **```
# df.groupby('<grouping column>').agg({'<aggregating column>':'<aggregating function>'})
# ```**
#
# Let's see this again by calculating the average years of experience for each gender.

# %%
emp.groupby('gender').agg({'experience': 'mean'})
# Out:
#         experience
# gender
# Female   12.910588
# Male     15.015472

# %% [markdown]
# # Grouping with Multiple Columns (use a list)
# To create groups based on distinct values from multiple columns, we will need to pass a list of these columns to the **`groupby`** method. Let's find the average years of experience for every unique combination of race and gender.

# %%
emp.groupby(['race', 'gender']).agg({'experience': 'mean'}).reset_index()
# Out:
#               race  gender  experience
# 0            Asian  Female   16.277778
# 1            Asian    Male   13.500000
# 2            Black  Female   13.555556
# 3            Black    Male   13.276074
# 4         Hispanic  Female   10.861386
# 5         Hispanic    Male   12.843537
# 6  Native American  Female   15.750000
# 7  Native American    Male   15.750000
# 8            White  Female   14.179487
# 9            White    Male   17.867816

# %% [markdown]
# ### What happened to our index?
# Both race and gender are not columns and have been pushed into the index. This is called a **multi-level index** and technically a **`MultiIndex`** object. **`race`** and **`gender`** are considered **levels** of the index. They are NOT columns. You'll notice that duplicated values do not repeat in an index when they immediately follow one another.
#
# ### The MultiIndex is confusing and not necessary for beginners
# In my opinion, this multi-level index only adds to confusion. By default, all grouping columns will be added to the index. From this point on, we will chain the **`reset_index`** method to return these levels to columns.

# %%
emp.groupby(['race', 'gender']).agg({'experience': 'mean'}).reset_index()
# Out:
#               race  gender  experience
# 0            Asian  Female   16.277778
# 1            Asian    Male   13.500000
# 2            Black  Female   13.555556
# 3            Black    Male   13.276074
# 4         Hispanic  Female   10.861386
# 5         Hispanic    Male   12.843537
# 6  Native American  Female   15.750000
# 7  Native American    Male   15.750000
# 8            White  Female   14.179487
# 9            White    Male   17.867816

# %% [markdown]
# ### Isn't it easier to read with a MultiIndex?
# The MultiIndex can make the results easier to read, but it makes further data analysis more difficult as you need to become familiar with special syntax just for the MultiIndex. This added complexity for beginners is not worth the benefit.

# %% [markdown]
# # Aggregating Multiple Columns
# To aggregate multiple columns, add the column name to the dictionary paired with its aggregation function. The aggregation functions can be different. The following finds the average salary and max years of experience for each gender.

# %%
emp.groupby('gender').agg({'salary': 'mean', 'experience': 'max'}).reset_index()
# Out:
#    gender        salary  experience
# 0  Female  50815.556650          41
# 1    Male  57966.976419          58

# %% [markdown]
# # Grouping and Aggregating with Multiple Columns
# We can combine the last two approaches to group with multiple columns along with multiple aggregating columns.
#
# The following finds the mean salary and max experience for every unique combination of race and gender. It might make things more readable by placing the each aggregating column on a separate line.

# %%
emp.groupby(['race', 'gender']).agg({'salary': 'mean', 
                                     'experience': 'max'}).reset_index()
# Out:
#               race  gender        salary  experience
# 0            Asian  Female  58304.222222          35
# 1            Asian    Male  60622.956522          39
# 2            Black  Female  48133.381643          37
# 3            Black    Male  51853.000000          48
# 4         Hispanic  Female  44216.960000          37
# 5         Hispanic    Male  55493.064057          41
# 6  Native American  Female  58844.333333          21
# 7  Native American    Male  68850.500000          25
# 8            White  Female  66415.527778          41
# 9            White    Male  63439.195745          58

# %% [markdown]
# # Multiple Aggregation Functions
# Let's say we want to find the min, max, mean, and median salary for each race. We do this by using a list of aggregating functions as the key in our **`agg`** dictionary.

# %%
emp.groupby('race').agg({'salary': ['min', 'max', 'mean', 'median']})
# Out:
#                   salary
#                      min       max          mean   median
# race
# Asian            26125.0  163228.0  60143.218391  55461.0
# Black            24960.0  186192.0  50366.588803  45926.0
# Hispanic         26104.0  165216.0  52533.456693  51194.0
# Native American  49379.0   81239.0  64562.142857  60347.0
# White            26125.0  210588.0  63834.575646  62540.0

# %% [markdown]
# ## What's up with those column names???
# The column names probably look pretty bizarre to you. Although it doesn't take much effort to decipher what each column means, the column names are not particularly friendly to work with.
#
# Pandas created a **multi-level column index** with two levels. These are difficult to work with. There isn't a standard way to deal with them like we did with the multi-level index from above.
#
# ## Renaming all the columns
# I recommend renaming all the columns after the aggregation. This is straightforward, but tedious. Assign the DataFrame's **`columns`** attribute to a list of desired column names. The list must be the same length as the original.

# %%
race_salary = emp.groupby('race').agg({'salary': ['min', 'max', 'mean', 'median']}).reset_index()
race_salary.columns = ['race', 'min salary', 'max salary', 'mean salary', 'median salary']
race_salary
# Out:
#               race  min salary  max salary   mean salary  median salary
# 0            Asian     26125.0    163228.0  60143.218391        55461.0
# 1            Black     24960.0    186192.0  50366.588803        45926.0
# 2         Hispanic     26104.0    165216.0  52533.456693        51194.0
# 3  Native American     49379.0     81239.0  64562.142857        60347.0
# 4            White     26125.0    210588.0  63834.575646        62540.0

# %% [markdown]
# If you are not planning on using the returned DataFrame then you don't need to bother renaming the columns, but having a single level index is going to be much easier to work with than a MultiIndex when you are first beginning your Pandas journey.
#
# ## No added functionality of a MultiIndex
# I actually don't think the MultiIndex offers much benefit. All data analysis is possible without it. There are some cool tricks you can do with it, but overall it will not prevent you from achieving any kind of analysis if you do not use it.

# %% [markdown]
# # Multiple Grouping Columns, Aggregating Columns, and Aggregating Functions
# You can make complex aggregations by having multiple grouping columns, aggregating columns, and aggregating functions.

# %%
rg_sal_exp = emp.groupby(['race', 'gender']) \
                .agg({'salary': ['min', 'max', 'mean', 'median'],
                      'experience': ['max', 'std']}).reset_index()
rg_sal_exp
# Out:
#               race  gender   salary                                   \
#                                 min       max          mean   median
# 0            Asian  Female  26125.0   95950.0  58304.222222  51514.5
# 1            Asian    Male  27914.0  163228.0  60622.956522  55461.0
# 2            Black  Female  24960.0  150416.0  48133.381643  40581.0
# 3            Black    Male  26125.0  186192.0  51853.000000  49150.0
# 4         Hispanic  Female  26125.0   96157.0  44216.960000  42837.5
# 5         Hispanic    Male  26104.0  165216.0  55493.064057  55437.0
# 6  Native American  Female  49379.0   68299.0  58844.333333  58855.0
# 7  Native American    Male  55461.0   81239.0  68850.500000  69351.0
# 8            White  Female  30888.0  178331.0  66415.527778  62783.0
# 9            White    Male  26125.0  210588.0  63439.195745  62540.0
#
#   experience
#          max        std
# 0         35   9.868581
# 1         39   9.645529
# 2         37   9.352362
# 3         48  10.290123
# 4         37   9.088487
# 5         41   9.859907
# 6         21   4.112988
# 7         25   8.098354
# 8         41  10.809740
# 9         58  11.783384

# %% [markdown]
# Again, I suggest renaming the columns for easier data manipulation.

# %%
rg_sal_exp.columns = ['race', 'gender', 'min salary', 'max salary', 'mean salary',
                      'median salary', 'max exp', 'std exp']
rg_sal_exp
# Out:
#               race  gender  min salary  max salary   mean salary  \
# 0            Asian  Female     26125.0     95950.0  58304.222222
# 1            Asian    Male     27914.0    163228.0  60622.956522
# 2            Black  Female     24960.0    150416.0  48133.381643
# 3            Black    Male     26125.0    186192.0  51853.000000
# 4         Hispanic  Female     26125.0     96157.0  44216.960000
# 5         Hispanic    Male     26104.0    165216.0  55493.064057
# 6  Native American  Female     49379.0     68299.0  58844.333333
# 7  Native American    Male     55461.0     81239.0  68850.500000
# 8            White  Female     30888.0    178331.0  66415.527778
# 9            White    Male     26125.0    210588.0  63439.195745
#
#    median salary  max exp    std exp
# 0        51514.5       35   9.868581
# 1        55461.0       39   9.645529
# 2        40581.0       37   9.352362
# 3        49150.0       48  10.290123
# 4        42837.5       37   9.088487
# 5        55437.0       41   9.859907
# 6        58855.0       21   4.112988
# 7        69351.0       25   8.098354
# 8        62783.0       41  10.809740
# 9        62540.0       58  11.783384

# %% [markdown]
# # Getting the size of each group
# Let's say we just want to know the number of rows in each group. The correct aggregation function is **`size`** and not **`count`** (this returns the number of non-missing values).

# %%
emp.groupby(['race', 'gender']).agg({'salary': 'size'}).reset_index()
# Out:
#               race  gender  salary
# 0            Asian  Female      18
# 1            Asian    Male      70
# 2            Black  Female     216
# 3            Black    Male     326
# 4         Hispanic  Female     101
# 5         Hispanic    Male     294
# 6  Native American  Female       4
# 7  Native American    Male       4
# 8            White  Female      78
# 9            White    Male     522

# %% [markdown]
# ### The aggregating column doesn't matter
# The same result will be returned regardless of what aggregating column we use since the size only depends on the number of rows and not on the actual values in the column. Using the department column does not change the output.

# %%
emp.groupby(['race', 'gender']).agg({'dept': 'size'}).reset_index()
# Out:
#               race  gender  dept
# 0            Asian  Female    18
# 1            Asian    Male    70
# 2            Black  Female   216
# 3            Black    Male   326
# 4         Hispanic  Female   101
# 5         Hispanic    Male   294
# 6  Native American  Female     4
# 7  Native American    Male     4
# 8            White  Female    78
# 9            White    Male   522

# %% [markdown]
# ## Alternative Syntax for size
# You can call the **`size`** method directly after grouping. This will return the same data as a Series.

# %%
emp.groupby(['race', 'gender']).size()
# Out:
# race             gender
# Asian            Female     18
#                  Male       70
# Black            Female    216
#                  Male      326
# Hispanic         Female    101
#                  Male      294
# Native American  Female      4
#                  Male        4
# White            Female     78
#                  Male      522
# dtype: int64

# %% [markdown]
# ## Rename the column when using `reset_index`
# When calling `reset_index` on a Series, like we did above, the new column name for the Series values will be the `name` attribute of the Series. If it doesn't exist (like in the example above) then you can supply the column name with the `name` parameter with `reset_index`.

# %%
emp.groupby(['race', 'gender']).size().reset_index(name='size')
# Out:
#               race  gender  size
# 0            Asian  Female    18
# 1            Asian    Male    70
# 2            Black  Female   216
# 3            Black    Male   326
# 4         Hispanic  Female   101
# 5         Hispanic    Male   294
# 6  Native American  Female     4
# 7  Native American    Male     4
# 8            White  Female    78
# 9            White    Male   522

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">For each department and gender find the number of unique position titles, the total number of employees and the average salary. Make sure there is no multi-index for the index or columns.</span>

# %%
emp1 = emp.groupby(['dept', 'gender']).agg({'title':['nunique','size'], 'salary':'mean'})
emp1.columns = ['unique position', '# employee', 'salary avg']
emp1.reset_index()
# Out:
#                               dept  gender  unique position  # employee  \
# 0          Health & Human Services  Female               47          82
# 1          Health & Human Services    Male               22          26
# 2     Houston Airport System (HAS)  Female               24          36
# 3     Houston Airport System (HAS)    Male               37          70
# 4    Houston Fire Department (HFD)  Female               13          21
# 5    Houston Fire Department (HFD)    Male               26         363
# 6    Houston Police Department-HPD  Female               38         155
# 7    Houston Police Department-HPD    Male               27         483
# 8               Parks & Recreation  Female               15          23
# 9               Parks & Recreation    Male               20          51
# 10  Public Works & Engineering-PWE  Female               55         108
# 11  Public Works & Engineering-PWE    Male               70         235
#
#       salary avg
# 0   48661.961538
# 1   59240.000000
# 2   53174.194444
# 3   54358.171429
# 4   52853.047619
# 5   59930.564470
# 6   52219.925170
# 7   63032.841121
# 8   40361.055556
# 9   38396.243243
# 10  51023.301887
# 11  49839.965957

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">For each department, race and gender find the maximum years of experience and salary.</span>

# %%
emp.groupby(['dept', 'race', 'gender']).agg({'experience':'max', 'salary':'max'}).reset_index()
# Out:
#                               dept             race  gender  experience  \
# 0          Health & Human Services            Asian  Female          23
# 1          Health & Human Services            Asian    Male          25
# 2          Health & Human Services            Black  Female          34
# 3          Health & Human Services            Black    Male          29
# 4          Health & Human Services         Hispanic  Female          25
# 5          Health & Human Services         Hispanic    Male          14
# 6          Health & Human Services  Native American  Female          17
# 7          Health & Human Services            White  Female          33
# 8          Health & Human Services            White    Male           8
# 9     Houston Airport System (HAS)            Asian  Female          23
# 10    Houston Airport System (HAS)            Asian    Male          22
# 11    Houston Airport System (HAS)            Black  Female          19
# 12    Houston Airport System (HAS)            Black    Male          32
# 13    Houston Airport System (HAS)         Hispanic  Female          25
# 14    Houston Airport System (HAS)         Hispanic    Male          27
# 15    Houston Airport System (HAS)  Native American  Female          21
# 16    Houston Airport System (HAS)            White  Female          24
# 17    Houston Airport System (HAS)            White    Male          19
# 18   Houston Fire Department (HFD)            Asian    Male           2
# 19   Houston Fire Department (HFD)            Black  Female          27
# 20   Houston Fire Department (HFD)            Black    Male          48
# 21   Houston Fire Department (HFD)         Hispanic  Female          21
# 22   Houston Fire Department (HFD)         Hispanic    Male          41
# 23   Houston Fire Department (HFD)  Native American    Male          20
# 24   Houston Fire Department (HFD)            White  Female          22
# 25   Houston Fire Department (HFD)            White    Male          39
# 26   Houston Police Department-HPD            Asian  Female          35
# 27   Houston Police Department-HPD            Asian    Male          39
# 28   Houston Police Department-HPD            Black  Female          37
# 29   Houston Police Department-HPD            Black    Male          37
# 30   Houston Police Department-HPD         Hispanic  Female          37
# 31   Houston Police Department-HPD         Hispanic    Male          40
# 32   Houston Police Department-HPD  Native American    Male          25
# 33   Houston Police Department-HPD            White  Female          41
# 34   Houston Police Department-HPD            White    Male          58
# 35              Parks & Recreation            Asian    Male          26
# 36              Parks & Recreation            Black  Female          28
# 37              Parks & Recreation            Black    Male          31
# 38              Parks & Recreation         Hispanic  Female          28
# 39              Parks & Recreation         Hispanic    Male          26
# 40              Parks & Recreation            White  Female           3
# 41              Parks & Recreation            White    Male          19
# 42  Public Works & Engineering-PWE            Asian  Female          13
# 43  Public Works & Engineering-PWE            Asian    Male          35
# 44  Public Works & Engineering-PWE            Black  Female          36
# 45  Public Works & Engineering-PWE            Black    Male          38
# 46  Public Works & Engineering-PWE         Hispanic  Female          37
# 47  Public Works & Engineering-PWE         Hispanic    Male          35
# 48  Public Works & Engineering-PWE            White  Female          35
# 49  Public Works & Engineering-PWE            White    Male          36
#
#       salary
# 0    94149.0
# 1    70864.0
# 2   103270.0
# 3   180416.0
# 4    65589.0
# 5    58406.0
# 6    58855.0
# 7   100791.0
# 8   120799.0
# 9    32157.0
# 10   77535.0
# 11  150416.0
# 12  186192.0
# 13   96157.0
# 14  115416.0
# 15   68299.0
# 16  128606.0
# 17  120916.0
# 18   43528.0
# 19   96668.0
# 20  130585.0
# 21   66523.0
# 22  165216.0
# 23   78355.0
# 24   74270.0
# 25  210588.0
# 26   91181.0
# 27  163228.0
# 28   91181.0
# 29  104455.0
# 30   77076.0
# 31   91181.0
# 32   81239.0
# 33  104455.0
# 34  199596.0
# 35   48651.0
# 36   57533.0
# 37   56014.0
# 38   83916.0
# 39   72280.0
# 40       NaN
# 41   85055.0
# 42   95950.0
# 43  124861.0
# 44   93089.0
# 45  104389.0
# 46   66449.0
# 47   90293.0
# 48  178331.0
# 49  141948.0

# %% [markdown]
# ## Use the college dataset for the rest of the problems

# %%
college = pd.read_csv('../data/college.csv')
college.head()
# Out:
#                                 instnm        city stabbr  hbcu  menonly  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    womenonly  relaffil  satvrmid  satmtmid  distanceonly         ...          \
# 0        0.0         0     424.0     420.0           0.0         ...
# 1        0.0         0     570.0     565.0           0.0         ...
# 2        0.0         1       NaN       NaN           1.0         ...
# 3        0.0         0     595.0     590.0           0.0         ...
# 4        0.0         0     425.0     430.0           0.0         ...
#
#    ugds_2mor  ugds_nra  ugds_unkn  pptug_ef  curroper  pctpell  pctfloan  \
# 0     0.0000    0.0059     0.0138    0.0656         1   0.7356    0.8284
# 1     0.0368    0.0179     0.0100    0.2607         1   0.3460    0.5214
# 2     0.0000    0.0000     0.2715    0.4536         1   0.6801    0.7795
# 3     0.0172    0.0332     0.0350    0.2146         1   0.3072    0.4596
# 4     0.0098    0.0243     0.0137    0.0892         1   0.7347    0.7554
#
#    ug25abv  md_earn_wne_p10  grad_debt_mdn_supp
# 0   0.1049            30300               33888
# 1   0.2422            39700             21941.5
# 2   0.8540            40100               23370
# 3   0.2640            45500               24097
# 4   0.1270            26600             33118.5
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Which city name appears the most frequently. Do this in two different ways. Do it once with and once without the `groupby` method?</span>

# %%
college.groupby('city').agg({'hbcu':'size'}).head()
# Out:
#           hbcu
# city
# ARTESIA      1
# Aberdeen     3
# Abilene      5
# Abingdon     2
# Abington     1

# %%
col = college.groupby('city').size()
col.reset_index(name='Size').head()
# Out:
#        city  Size
# 0   ARTESIA     1
# 1  Aberdeen     3
# 2   Abilene     5
# 3  Abingdon     2
# 4  Abington     1

# %%
# another way to do it would be
college['city'].value_counts().head()
# Out:
# New York       87
# Chicago        78
# Houston        72
# Los Angeles    56
# Miami          51
# Name: city, dtype: int64

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Does the city **`Houston`** only appear in the state of **`Texas`**?</span>

# %%
states = college.groupby('city').agg({'stabbr':'nunique'})
states.loc['Houston']
# Out:
# stabbr    2
# Name: Houston, dtype: int64

# %%
filt = college['city'] == 'Houston'
college.loc[filt,'stabbr'].unique()
# Out:
# array(['TX', 'MO'], dtype=object)

# %%
college.loc[filt,'stabbr'].value_counts()
# Out:
# TX    71
# MO     1
# Name: stabbr, dtype: int64

# %% [markdown]
# ### Problem 5
# <span  style="color:green; font-size:16px">Find the maximum undergraduate population for each state?</span>

# %%
under = college.groupby('stabbr').agg({'ugds':'max'})
under.head()
# Out:
#             ugds
# stabbr
# AK       12865.0
# AL       29851.0
# AR       21405.0
# AS        1276.0
# AZ      151558.0

# %% [markdown]
# ### Problem 6
# <span  style="color:green; font-size:16px">Among colleges that have the largest undergrad population for each state, what is the difference between the most and least populous college?</span>

# %%
under.sort_values('ugds', ascending=False).head()
# Out:
#             ugds
# stabbr
# AZ      151558.0
# IN       77657.0
# FL       61470.0
# TX       59920.0
# VA       49340.0

# %%
under.max() - under.min()
# Out:
# ugds    150956.0
# dtype: float64

# %% [markdown]
# ### Problem 7: Advanced
# <span  style="color:green; font-size:16px">Find the name and population of the largest college per state.</span>

# %%
pop = college.groupby('stabbr').agg({'ugds':'idxmax'})
pop.head()
# Out:
#         ugds
# stabbr
# AK        60
# AL         5
# AR       137
# AS      4138
# AZ      7116

# %%
locs = pop['ugds']
locs
# Out:
# stabbr
# AK      60
# AL       5
# AR     137
# AS    4138
# AZ    7116
# CA    1299
# CO     574
# CT     641
# DC     701
# DE     691
# FL     793
# FM    4214
# GA     909
# GU    4140
# HI     952
# IA    4318
# ID     979
# IL    1049
# IN    1189
# KS    1363
# KY    1424
# LA    1486
# MA    1690
# MD    1589
# ME    1542
# MH    4561
# MI    1818
# MN    1906
# MO    2061
# MP    4141
# MS    1978
# MT    2127
# NC    2726
# ND    2788
# NE    2159
# NH    2197
# NJ    2284
# NM    2304
# NV    2172
# NY    2615
# OH    2943
# OK    3040
# OR    3116
# PA    3304
# PR    4172
# PW    4215
# RI    3410
# SC    3458
# SD    3497
# TN    3592
# TX    3711
# UT    5140
# VA    3880
# VI    4216
# VT    3849
# WA    4008
# WI    4123
# WV    5817
# WY    4137
# Name: ugds, dtype: int64

# %% [markdown]
# ### Problem 8
# <span  style="color:green; font-size:16px">Do distance only schools tend to have more or less student population than non-distance-only schools?</span>

# %%
college.groupby('distanceonly').agg({'ugds':'mean'})
# Out:
#                      ugds
# distanceonly
# 0.0           2334.648135
# 1.0           6245.743590

# %% [markdown]
# ### Problem 9
# <span  style="color:green; font-size:16px">Do distance only schools tend to be more or less religously affiliated than non-distance-only schools?</span>

# %%
college.groupby('distanceonly').agg({'relaffil':'mean'})
# Out:
#               relaffil
# distanceonly
# 0.0           0.149635
# 1.0           0.050000

# %% [markdown]
# ### Problem 10
# <span  style="color:green; font-size:16px">What state has the lowest percentage of currently operating schools of those that have religious affiliation?</span>

# %%
filt = college['relaffil'] == 1
coll = college[filt]
col_mean = coll.groupby('stabbr').agg({'curroper':'mean'})
col_mean.head()
# Out:
#         curroper
# stabbr
# AK      1.000000
# AL      0.916667
# AR      0.944444
# AZ      0.444444
# CA      0.585366

# %%
col_mean.sort_values('curroper').head()
# Out:
#         curroper
# stabbr
# UT      0.400000
# AZ      0.444444
# NV      0.500000
# CA      0.585366
# CT      0.647059

# %% [markdown]
# ### Problem 11
# <span  style="color:green; font-size:16px">Trim the **`college`** DataFrame to only the 'race' columns - those beginning with **`ugds_`**. Create a new column called **`ugds_other`** that is the sum of any race column that averages under 4% for the entire dataset.</span>

# %%
college
# Out:
#                                                  instnm              city  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# 5                             The University of Alabama        Tuscaloosa
# 6                     Central Alabama Community College    Alexander City
# 7                               Athens State University            Athens
# 8                       Auburn University at Montgomery        Montgomery
# 9                                     Auburn University            Auburn
# 10                          Birmingham Southern College        Birmingham
# 11               Chattahoochee Valley Community College       Phenix City
# 12                            Concordia College Alabama             Selma
# 13                          South University-Montgomery        Montgomery
# 14                   Enterprise State Community College        Enterprise
# 15             James H Faulkner State Community College       Bay Minette
# 16                                  Faulkner University        Montgomery
# 17                      Gadsden State Community College           Gadsden
# 18                 New Beginning College of Cosmetology       Albertville
# 19      George C Wallace State Community College-Dothan            Dothan
# 20    George C Wallace State Community College-Hance...        Hanceville
# 21       George C Wallace State Community College-Selma             Selma
# 22                        Herzing University-Birmingham        Birmingham
# 23                                   Huntingdon College        Montgomery
# 24                        Heritage Christian University          Florence
# 25      J F Drake State Community and Technical College        Huntsville
# 26                        Jacksonville State University      Jacksonville
# 27                    Jefferson Davis Community College           Brewton
# 28                    Jefferson State Community College        Birmingham
# 29               John C Calhoun State Community College            Tanner
# ...                                                 ...               ...
# 7505                   Strayer University-Lawrenceville     Lawrenceville
# 7506                      Strayer University-Piscataway        Piscataway
# 7507                                 Utah County Campus              Orem
# 7508                       L'esprit Academy - Royal Oak         Royal Oak
# 7509     National Career Institute - Jersey City Branch       Jersey City
# 7510                     Strayer University-Cobb Campus           Atlanta
# 7511                   Strayer University-Morrow Campus            Morrow
# 7512                  Strayer University-Roswell Campus           Roswell
# 7513             Strayer University-Douglasville Campus      Douglasville
# 7514                 Strayer University-Lithonia Campus          Lithonia
# 7515                 Strayer University-Savannah Campus          Savannah
# 7516                  Strayer University-Augusta Campus           Augusta
# 7517                        Strayer University-Columbus          Columbus
# 7518                 Strayer University-Columbia Campus          Columbia
# 7519               Strayer University-Charleston Campus  North Charleston
# 7520                          Strayer University-Irving            Irving
# 7521                            Strayer University-Katy           Houston
# 7522               Strayer University-Northwest Houston           Houston
# 7523                           Strayer University-Plano             Plano
# 7524                      Strayer University-Cedar Hill        Cedar Hill
# 7525                    Strayer University-North Dallas            Dallas
# 7526                     Strayer University-San Antonio       San Antonio
# 7527                        Strayer University-Stafford          Stafford
# 7528                           WestMed College - Merced            Merced
# 7529                                    Vantage College           El Paso
# 7530         SAE Institute of Technology  San Francisco        Emeryville
# 7531                  Rasmussen College - Overland Park     Overland Park
# 7532  National Personal Training Institute of Cleveland  Highland Heights
# 7533  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7534            Excel Learning Center-San Antonio South       San Antonio
#
#      stabbr  hbcu  menonly  womenonly  relaffil  satvrmid  satmtmid  \
# 0        AL   1.0      0.0        0.0         0     424.0     420.0
# 1        AL   0.0      0.0        0.0         0     570.0     565.0
# 2        AL   0.0      0.0        0.0         1       NaN       NaN
# 3        AL   0.0      0.0        0.0         0     595.0     590.0
# 4        AL   1.0      0.0        0.0         0     425.0     430.0
# 5        AL   0.0      0.0        0.0         0     555.0     565.0
# 6        AL   0.0      0.0        0.0         0       NaN       NaN
# 7        AL   0.0      0.0        0.0         0       NaN       NaN
# 8        AL   0.0      0.0        0.0         0     486.0     509.0
# 9        AL   0.0      0.0        0.0         0     575.0     588.0
# 10       AL   0.0      0.0        0.0         1     560.0     560.0
# 11       AL   0.0      0.0        0.0         0       NaN       NaN
# 12       AL   1.0      0.0        0.0         1     420.0     400.0
# 13       AL   0.0      0.0        0.0         0       NaN       NaN
# 14       AL   0.0      0.0        0.0         0       NaN       NaN
# 15       AL   0.0      0.0        0.0         0       NaN       NaN
# 16       AL   0.0      0.0        0.0         1       NaN       NaN
# 17       AL   1.0      0.0        0.0         0       NaN       NaN
# 18       AL   0.0      0.0        0.0         0       NaN       NaN
# 19       AL   0.0      0.0        0.0         0       NaN       NaN
# 20       AL   0.0      0.0        0.0         0       NaN       NaN
# 21       AL   0.0      0.0        0.0         0       NaN       NaN
# 22       AL   0.0      0.0        0.0         0       NaN       NaN
# 23       AL   0.0      0.0        0.0         1     510.0     490.0
# 24       AL   0.0      0.0        0.0         1       NaN       NaN
# 25       AL   1.0      0.0        0.0         0       NaN       NaN
# 26       AL   0.0      0.0        0.0         0     495.0     485.0
# 27       AL   0.0      0.0        0.0         0       NaN       NaN
# 28       AL   0.0      0.0        0.0         0       NaN       NaN
# 29       AL   0.0      0.0        0.0         0       NaN       NaN
# ...     ...   ...      ...        ...       ...       ...       ...
# 7505     NJ   NaN      NaN        NaN         1       NaN       NaN
# 7506     NJ   NaN      NaN        NaN         1       NaN       NaN
# 7507     UT   NaN      NaN        NaN         1       NaN       NaN
# 7508     MI   NaN      NaN        NaN         1       NaN       NaN
# 7509     NJ   NaN      NaN        NaN         1       NaN       NaN
# 7510     GA   NaN      NaN        NaN         1       NaN       NaN
# 7511     GA   NaN      NaN        NaN         1       NaN       NaN
# 7512     GA   NaN      NaN        NaN         1       NaN       NaN
# 7513     GA   NaN      NaN        NaN         1       NaN       NaN
# 7514     GA   NaN      NaN        NaN         1       NaN       NaN
# 7515     GA   NaN      NaN        NaN         1       NaN       NaN
# 7516     GA   NaN      NaN        NaN         1       NaN       NaN
# 7517     GA   NaN      NaN        NaN         1       NaN       NaN
# 7518     SC   NaN      NaN        NaN         1       NaN       NaN
# 7519     SC   NaN      NaN        NaN         1       NaN       NaN
# 7520     TX   NaN      NaN        NaN         1       NaN       NaN
# 7521     TX   NaN      NaN        NaN         1       NaN       NaN
# 7522     TX   NaN      NaN        NaN         1       NaN       NaN
# 7523     TX   NaN      NaN        NaN         1       NaN       NaN
# 7524     TX   NaN      NaN        NaN         1       NaN       NaN
# 7525     TX   NaN      NaN        NaN         1       NaN       NaN
# 7526     TX   NaN      NaN        NaN         1       NaN       NaN
# 7527     TX   NaN      NaN        NaN         1       NaN       NaN
# 7528     CA   NaN      NaN        NaN         1       NaN       NaN
# 7529     TX   NaN      NaN        NaN         1       NaN       NaN
# 7530     CA   NaN      NaN        NaN         1       NaN       NaN
# 7531     KS   NaN      NaN        NaN         1       NaN       NaN
# 7532     OH   NaN      NaN        NaN         1       NaN       NaN
# 7533     CA   NaN      NaN        NaN         1       NaN       NaN
# 7534     TX   NaN      NaN        NaN         1       NaN       NaN
#
#       distanceonly         ...          ugds_2mor  ugds_nra  ugds_unkn  \
# 0              0.0         ...             0.0000    0.0059     0.0138
# 1              0.0         ...             0.0368    0.0179     0.0100
# 2              1.0         ...             0.0000    0.0000     0.2715
# 3              0.0         ...             0.0172    0.0332     0.0350
# 4              0.0         ...             0.0098    0.0243     0.0137
# 5              0.0         ...             0.0261    0.0268     0.0026
# 6              0.0         ...             0.0000    0.0000     0.0019
# 7              0.0         ...             0.0174    0.0057     0.0334
# 8              0.0         ...             0.0297    0.0397     0.0246
# 9              0.0         ...             0.0000    0.0100     0.0140
# 10             0.0         ...             0.0051    0.0000     0.0051
# 11             0.0         ...             0.0151    0.0000     0.0139
# 12             0.0         ...             0.0031    0.0466     0.0000
# 13             0.0         ...             0.0000    0.0019     0.0326
# 14             0.0         ...             0.0254    0.0012     0.0069
# 15             0.0         ...             0.0152    0.0007     0.0009
# 16             0.0         ...             0.0173    0.0182     0.0258
# 17             0.0         ...             0.0185    0.0150     0.0169
# 18             0.0         ...             0.0000    0.0000     0.0000
# 19             0.0         ...             0.0126    0.0000     0.0009
# 20             0.0         ...             0.0000    0.0059     0.0183
# 21             0.0         ...             0.0033    0.0040     0.0443
# 22             0.0         ...             0.0563    0.0000     0.0397
# 23             0.0         ...             0.0261    0.0061     0.0827
# 24             0.0         ...             0.0000    0.0161     0.0323
# 25             0.0         ...             0.0185    0.0000     0.0062
# 26             0.0         ...             0.0000    0.0234     0.0280
# 27             0.0         ...             0.0184    0.0000     0.0397
# 28             0.0         ...             0.0301    0.0054     0.0001
# 29             0.0         ...             0.0428    0.0062     0.0162
# ...            ...         ...                ...       ...        ...
# 7505           NaN         ...                NaN       NaN        NaN
# 7506           NaN         ...                NaN       NaN        NaN
# 7507           NaN         ...                NaN       NaN        NaN
# 7508           NaN         ...                NaN       NaN        NaN
# 7509           NaN         ...                NaN       NaN        NaN
# 7510           NaN         ...                NaN       NaN        NaN
# 7511           NaN         ...                NaN       NaN        NaN
# 7512           NaN         ...                NaN       NaN        NaN
# 7513           NaN         ...                NaN       NaN        NaN
# 7514           NaN         ...                NaN       NaN        NaN
# 7515           NaN         ...                NaN       NaN        NaN
# 7516           NaN         ...                NaN       NaN        NaN
# 7517           NaN         ...                NaN       NaN        NaN
# 7518           NaN         ...                NaN       NaN        NaN
# 7519           NaN         ...                NaN       NaN        NaN
# 7520           NaN         ...                NaN       NaN        NaN
# 7521           NaN         ...                NaN       NaN        NaN
# 7522           NaN         ...                NaN       NaN        NaN
# 7523           NaN         ...                NaN       NaN        NaN
# 7524           NaN         ...                NaN       NaN        NaN
# 7525           NaN         ...                NaN       NaN        NaN
# 7526           NaN         ...                NaN       NaN        NaN
# 7527           NaN         ...                NaN       NaN        NaN
# 7528           NaN         ...                NaN       NaN        NaN
# 7529           NaN         ...                NaN       NaN        NaN
# 7530           NaN         ...                NaN       NaN        NaN
# 7531           NaN         ...                NaN       NaN        NaN
# 7532           NaN         ...                NaN       NaN        NaN
# 7533           NaN         ...                NaN       NaN        NaN
# 7534           NaN         ...                NaN       NaN        NaN
#
#       pptug_ef  curroper  pctpell  pctfloan  ug25abv    md_earn_wne_p10  \
# 0       0.0656         1   0.7356    0.8284   0.1049              30300
# 1       0.2607         1   0.3460    0.5214   0.2422              39700
# 2       0.4536         1   0.6801    0.7795   0.8540              40100
# 3       0.2146         1   0.3072    0.4596   0.2640              45500
# 4       0.0892         1   0.7347    0.7554   0.1270              26600
# 5       0.0844         1   0.2040    0.4010   0.0853              41900
# 6       0.3882         1   0.5892    0.3977   0.3153              27500
# 7       0.5517         1   0.4088    0.6296   0.6410              39000
# 8       0.2853         1   0.4192    0.5803   0.2930              35000
# 9       0.0862         1   0.1610    0.3494   0.0415              45700
# 10      0.0017         1   0.1920    0.4809   0.0152              44200
# 11      0.4198         1   0.6369    0.2537   0.3876              26100
# 12      0.1056         1   0.8667    0.9333   0.2367              19900
# 13      0.3238         1   0.6845    0.7129   0.5726              28800
# 14      0.3823         1   0.4895    0.2263   0.3399              24600
# 15      0.4104         1   0.4725    0.3741   0.2909              28700
# 16      0.2302         1   0.5812    0.7253   0.4589              37200
# 17      0.4523         1   0.5734    0.0000   0.3733              25700
# 18      0.0783         1   0.8224    0.8553   0.3933                NaN
# 19      0.4787         1   0.5501    0.0000   0.3920              26600
# 20      0.4203         1   0.5026    0.4192   0.3229              28800
# 21      0.3840         1   0.7645    0.0000   0.3318              24200
# 22      0.5497         1   0.6541    0.7736   0.7813              42300
# 23      0.2097         1   0.3982    0.7153   0.1937              36500
# 24      0.4355         1   0.6087    0.4493   0.5942  PrivacySuppressed
# 25      0.4394         1   0.5763    0.0000   0.4555              22300
# 26      0.1989         1   0.4428    0.6825   0.2200              34600
# 27      0.4424         1   0.5765    0.0000   0.4060              25400
# 28      0.6050         1   0.3372    0.2101   0.3671              29400
# 29      0.5795         1   0.3933    0.3024   0.3688              27400
# ...        ...       ...      ...       ...      ...                ...
# 7505       NaN         1      NaN       NaN      NaN              49200
# 7506       NaN         1      NaN       NaN      NaN              49200
# 7507       NaN         1      NaN       NaN      NaN                NaN
# 7508       NaN         1      NaN       NaN      NaN                NaN
# 7509       NaN         1      NaN       NaN      NaN                NaN
# 7510       NaN         1      NaN       NaN      NaN              49200
# 7511       NaN         1      NaN       NaN      NaN              49200
# 7512       NaN         1      NaN       NaN      NaN              49200
# 7513       NaN         1      NaN       NaN      NaN              49200
# 7514       NaN         1      NaN       NaN      NaN              49200
# 7515       NaN         1      NaN       NaN      NaN              49200
# 7516       NaN         1      NaN       NaN      NaN              49200
# 7517       NaN         0      NaN       NaN      NaN              49200
# 7518       NaN         1      NaN       NaN      NaN              49200
# 7519       NaN         1      NaN       NaN      NaN              49200
# 7520       NaN         1      NaN       NaN      NaN              49200
# 7521       NaN         1      NaN       NaN      NaN              49200
# 7522       NaN         1      NaN       NaN      NaN              49200
# 7523       NaN         1      NaN       NaN      NaN              49200
# 7524       NaN         1      NaN       NaN      NaN                NaN
# 7525       NaN         1      NaN       NaN      NaN                NaN
# 7526       NaN         1      NaN       NaN      NaN                NaN
# 7527       NaN         1      NaN       NaN      NaN                NaN
# 7528       NaN         1      NaN       NaN      NaN                NaN
# 7529       NaN         1      NaN       NaN      NaN                NaN
# 7530       NaN         1      NaN       NaN      NaN                NaN
# 7531       NaN         1      NaN       NaN      NaN                NaN
# 7532       NaN         1      NaN       NaN      NaN                NaN
# 7533       NaN         1      NaN       NaN      NaN                NaN
# 7534       NaN         1      NaN       NaN      NaN                NaN
#
#       grad_debt_mdn_supp
# 0                  33888
# 1                21941.5
# 2                  23370
# 3                  24097
# 4                33118.5
# 5                  23750
# 6                  16127
# 7                  18595
# 8                  21335
# 9                  21831
# 10                 27000
# 11                  9000
# 12     PrivacySuppressed
# 13                 25167
# 14                  8273
# 15                 11000
# 16                 22000
# 17     PrivacySuppressed
# 18                  5500
# 19     PrivacySuppressed
# 20                 11186
# 21     PrivacySuppressed
# 22               23216.5
# 23                 26230
# 24     PrivacySuppressed
# 25     PrivacySuppressed
# 26                 23000
# 27     PrivacySuppressed
# 28                8916.5
# 29                 10500
# ...                  ...
# 7505             36173.5
# 7506             36173.5
# 7507                7667
# 7508                9833
# 7509                9500
# 7510             36173.5
# 7511             36173.5
# 7512             36173.5
# 7513             36173.5
# 7514             36173.5
# 7515             36173.5
# 7516             36173.5
# 7517             36173.5
# 7518             36173.5
# 7519             36173.5
# 7520             36173.5
# 7521             36173.5
# 7522             36173.5
# 7523             36173.5
# 7524             36173.5
# 7525             36173.5
# 7526             36173.5
# 7527             36173.5
# 7528             15623.5
# 7529                9500
# 7530                9500
# 7531               21163
# 7532                6333
# 7533   PrivacySuppressed
# 7534               12125
#
# [7535 rows x 27 columns]

# %% [markdown]
# ### Problem 12
# <span  style="color:green; font-size:16px">Which top 5 historically black colleges that have the highest white percentage?</span>
