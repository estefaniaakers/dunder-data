# %% [markdown]
# # Notes - 04. Time Series

# %% [markdown]
# date - only month, day year
# time - only hour, minute, second, part of second
# datetime - date and time together
#
# pandas - precision of a nano second unity
#
# #### datetime module in Python
# import datetime
#
# datetime data
#
# timedelta = amount of time

# %%
import pandas as pd

# %%
pd.to_datetime('2018/12/22') #convert a string to a datetime -> Timestamp is a datetime in Pandas
# Out:
# Timestamp('2018-12-22 00:00:00')

# %%
pd.to_datetime('Jan 3rd, 2013 5:43') #international standart for time
# Out:
# Timestamp('2013-01-03 05:43:00')

# %%
pd.to_datetime(1000) #if you use a integer is gonna past the epoc, u can use unit='d' - 1000 days after the epox
# Out:
# Timestamp('1970-01-01 00:00:00.000001')

# %%
bikes = pd.read_csv('../data/bikes.csv')
bikes.head()
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4    13168  Subscriber   Male  2013-07-01 11:16:00  2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0     Wells St & Walton St     41.899930
# 2       -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 3       -87.653449              19.0   Clark St & Randolph St     41.884576
# 4       -87.677692              19.0   Damen Ave & Pierce Ave     41.909396
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 2     -87.629521            23.0         73.0        10.0        16.1
# 3     -87.631890            31.0         72.0        10.0        16.1
# 4     -87.677692            19.0         73.0        10.0        17.3
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 2        -9999.0  mostlycloudy
# 3        -9999.0  mostlycloudy
# 4        -9999.0  partlycloudy

# %%
bikes['starttime'] = pd.to_datetime(bikes['starttime']) #or you can use parse_dates=['starttime', 'stoptime']
bikes.head()
bikes['stoptime'] = pd.to_datetime(bikes['stoptime']) #or you can use parse_dates=['starttime', 'stoptime']
bikes.head()
# Out:
#    trip_id    usertype gender           starttime            stoptime  \
# 0     7147  Subscriber   Male 2013-06-28 19:01:00 2013-06-28 19:17:00
# 1     7524  Subscriber   Male 2013-06-28 22:53:00 2013-06-28 23:03:00
# 2    10927  Subscriber   Male 2013-06-30 14:43:00 2013-06-30 15:01:00
# 3    12907  Subscriber   Male 2013-07-01 10:05:00 2013-07-01 10:16:00
# 4    13168  Subscriber   Male 2013-07-01 11:16:00 2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0     Wells St & Walton St     41.899930
# 2       -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 3       -87.653449              19.0   Clark St & Randolph St     41.884576
# 4       -87.677692              19.0   Damen Ave & Pierce Ave     41.909396
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 2     -87.629521            23.0         73.0        10.0        16.1
# 3     -87.631890            31.0         72.0        10.0        16.1
# 4     -87.677692            19.0         73.0        10.0        17.3
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 2        -9999.0  mostlycloudy
# 3        -9999.0  mostlycloudy
# 4        -9999.0  partlycloudy

# %%
bikes.dtypes
# Out:
# trip_id                       int64
# usertype                     object
# gender                       object
# starttime            datetime64[ns]
# stoptime                     object
# tripduration                  int64
# from_station_name            object
# latitude_start              float64
# longitude_start             float64
# dpcapacity_start            float64
# to_station_name              object
# latitude_end                float64
# longitude_end               float64
# dpcapacity_end              float64
# temperature                 float64
# visibility                  float64
# wind_speed                  float64
# precipitation               float64
# events                       object
# dtype: object

# %%
bikes.loc[0, 'starttime'] #dexplo library
# Out:
# Timestamp('2013-06-28 19:01:00')

# %%
start = bikes['starttime']

# %%
start.dt.date.head() #get power of your datetime str get power of your string
# Out:
# 0    2013-06-28
# 1    2013-06-28
# 2    2013-06-30
# 3    2013-07-01
# 4    2013-07-01
# Name: starttime, dtype: object

# %% [markdown]
# #### Timedelta
# an amount of time
#     if you subtract two date times you will have a timedelta

# %%
pd.to_timedelta('4 days 5 hours')
# Out:
# Timedelta('4 days 05:00:00')

# %%
bikes['tripduration_calc'] = bikes['stoptime'] - bikes['starttime']
tdc = bikes['tripduration_calc']
tdc.head()
# Out:
# 0   00:16:00
# 1   00:10:00
# 2   00:18:00
# 3   00:11:00
# 4   00:02:00
# Name: tripduration_calc, dtype: timedelta64[ns]

# %% [markdown]
# # 02. INTRO TO TIME SERIES
#
# * using JSON to get data from the api https://iextrading.com/
# * this is one api really simple

# %%
#IEX API
url = 'https://api.iextrading.com/1.0/stock/aapl/chart/5y'

# %%
stocks = pd.read_json(url)
stocks.head() #already convert the dates to datetime
# Out:
#      change  changeOverTime  changePercent    close       date     high  \
# 0  2.762500        0.000000          3.838  74.7447 2013-12-23  74.8273
# 1 -0.317288       -0.004244         -0.424  74.4275 2013-12-24  74.9794
# 2 -0.494284       -0.010857         -0.664  73.9332 2013-12-26  74.6674
# 3 -0.499533       -0.017541         -0.676  73.4336 2013-12-27  74.0000
# 4 -0.730286       -0.027310         -0.994  72.7034 2013-12-30  73.4336
#
#         label      low     open  unadjustedVolume     volume     vwap
# 0  Dec 23, 13  73.7837  74.4707          17903833  125326831  74.4027
# 1  Dec 24, 13  74.2124  74.7185           5984105   41888735  74.5717
# 2  Dec 26, 13  73.8645  74.4838           7286005   51002035  74.1287
# 3  Dec 27, 13  73.3563  73.9227           8067331   56471317  73.5374
# 4  Dec 30, 13  72.4150  73.0888           9058246   63407722  72.7190

# %%
#if u have datetime u can use this on the index - will give u a nice advantage in some cases

# %%
stocks = stocks.set_index('date')

# %%
stocks.head()
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2013-12-23  2.762500        0.000000          3.838  74.7447  74.8273
# 2013-12-24 -0.317288       -0.004244         -0.424  74.4275  74.9794
# 2013-12-26 -0.494284       -0.010857         -0.664  73.9332  74.6674
# 2013-12-27 -0.499533       -0.017541         -0.676  73.4336  74.0000
# 2013-12-30 -0.730286       -0.027310         -0.994  72.7034  73.4336
#
#                  label      low     open  unadjustedVolume     volume     vwap
# date
# 2013-12-23  Dec 23, 13  73.7837  74.4707          17903833  125326831  74.4027
# 2013-12-24  Dec 24, 13  74.2124  74.7185           5984105   41888735  74.5717
# 2013-12-26  Dec 26, 13  73.8645  74.4838           7286005   51002035  74.1287
# 2013-12-27  Dec 27, 13  73.3563  73.9227           8067331   56471317  73.5374
# 2013-12-30  Dec 30, 13  72.4150  73.0888           9058246   63407722  72.7190

# %%
#subselection with date time on the index
stocks.loc['2014-12-24'].head()
# Out:
# change           -0.494289
# changeOverTime    0.397596
# changePercent       -0.471
# close              104.463
# high               105.116
# Name: 2014-12-24 00:00:00, dtype: object

# %%
stocks.loc['2014-12-22':'2015-12-22'].head()
# Out:
#               change  changeOverTime  changePercent     close      high  \
# date
# 2014-12-22  1.081800        0.409200          1.038  105.3302  105.8432
# 2014-12-23 -0.373049        0.404209         -0.354  104.9572  105.6940
# 2014-12-24 -0.494289        0.397596         -0.471  104.4629  105.1157
# 2014-12-26  1.846600        0.422302          1.768  106.3095  106.8038
# 2014-12-29 -0.074610        0.421303         -0.070  106.2349  107.0369
#
#                  label       low      open  unadjustedVolume    volume  \
# date
# 2014-12-22  Dec 22, 14  104.4256  104.6028          45167549  45167549
# 2014-12-23  Dec 23, 14  104.8826  105.6007          26028419  26028419
# 2014-12-24  Dec 24, 14  104.4629  104.9945          14479611  14479611
# 2014-12-26  Dec 26, 14  104.4629  104.5468          33720951  33720951
# 2014-12-29  Dec 29, 14  106.0390  106.1230          27598920  27598920
#
#                 vwap
# date
# 2014-12-22  105.2148
# 2014-12-23  105.1756
# 2014-12-24  104.6175
# 2014-12-26  105.9206
# 2014-12-29  106.5392

# %%
#PARTIAL STRING MATCHING - get the whole month, if is just the year would be all the transactions on that year
stocks.loc['2014-01'].head()
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2014-01-02 -1.034500       -0.029749         -1.406  72.5211  73.0324
# 2014-01-03 -1.593000       -0.051062         -2.197  70.9281  72.5958
# 2014-01-06  0.386777       -0.045887          0.545  71.3149  71.6912
# 2014-01-07 -0.510346       -0.052714         -0.716  70.8046  71.5811
# 2014-01-08  0.448723       -0.046711          0.634  71.2533  71.5286
#
#                 label      low     open  unadjustedVolume     volume     vwap
# date
# 2014-01-02  Jan 2, 14  72.3757  72.8554           8398851   58791957  72.1961
# 2014-01-03  Jan 3, 14  70.8560  72.4857          14043410   98303870  71.5008
# 2014-01-06  Jan 6, 14  69.9605  70.4653          14765593  103359151  70.9303
# 2014-01-07  Jan 7, 14  70.5276  71.3660          11347538   79432766  71.7785
# 2014-01-08  Jan 8, 14  70.6279  70.6436           9240955   64686685  71.2531

# %%
stocks.loc['2014-6-1':'2014-8'].head()
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2014-06-02 -0.574197        0.110202         -0.687  82.9817  83.7975
# 2014-06-09  1.363600        0.158327          1.600  86.5788  86.7451
# 2014-06-16  0.850081        0.139784          1.008  85.1928  85.7010
# 2014-06-23 -0.073920        0.122848         -0.088  83.9269  84.6568
# 2014-06-30  0.877800        0.148808          1.033  85.8673  86.6018
#
#                  label      low     open  unadjustedVolume    volume     vwap
# date
# 2014-06-02   Jun 2, 14  82.1699  83.6826          13191129  92337903  83.0617
# 2014-06-09   Jun 9, 14  84.7769  85.6548          75414804  75414804  86.0268
# 2014-06-16  Jun 16, 14  84.4998  84.5552          35561270  35561270  85.1030
# 2014-06-23  Jun 23, 14  83.7144  84.3796          43694391  43694391  84.0226
# 2014-06-30  Jun 30, 14  85.0911  85.1004          49589028  49589028  85.9819

# %%
from Ipython.display import Iframe
#
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-8b237e55591e> in <module>()
# ----> 1 from Ipython.display import Iframe
#       2 #
#
# ModuleNotFoundError: No module named 'Ipython'

# %%
#just work with datetime index
stocks.asfreq('M').head() #every last day of each month - LOOK INTO THE ALIASES
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2013-12-31  0.852221       -0.015909          1.172  73.5556  73.5897
# 2014-01-31  0.107251       -0.121892          0.164  65.6339  65.7558
# 2014-02-28 -0.188612       -0.071392         -0.271  69.4085  70.2672
# 2014-03-31 -0.015825       -0.052864         -0.022  70.7934  71.3303
# 2014-04-30 -0.295446        0.041278         -0.378  77.8300  79.0619
#
#                  label      low     open  unadjustedVolume       volume  \
# date
# 2013-12-31  Dec 31, 13  72.6352  72.6575         7974196.0   55819372.0
# 2014-01-31  Jan 31, 14  64.7096  64.9233        16619492.0  116336444.0
# 2014-02-28  Feb 28, 14  68.8651  69.7831        13296379.0   93074653.0
# 2014-03-31  Mar 31, 14  70.6866  71.1219         6023884.0   42167188.0
# 2014-04-30  Apr 30, 14  77.7918  78.1664        16317269.0  114220883.0
#
#                vwap
# date
# 2013-12-31  73.3833
# 2014-01-31  71.6528
# 2014-02-28  69.5702
# 2014-03-31  70.9193
# 2014-04-30  78.3607

# %%
stocks.asfreq('2M').head()
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2013-12-31  0.852221       -0.015909          1.172  73.5556  73.5897
# 2014-02-28 -0.188612       -0.071392         -0.271  69.4085  70.2672
# 2014-04-30 -0.295446        0.041278         -0.378  77.8300  79.0619
# 2014-06-30  0.877800        0.148808          1.033  85.8673  86.6018
# 2014-08-31       NaN             NaN            NaN      NaN      NaN
#
#                  label      low     open  unadjustedVolume       volume  \
# date
# 2013-12-31  Dec 31, 13  72.6352  72.6575         7974196.0   55819372.0
# 2014-02-28  Feb 28, 14  68.8651  69.7831        13296379.0   93074653.0
# 2014-04-30  Apr 30, 14  77.7918  78.1664        16317269.0  114220883.0
# 2014-06-30  Jun 30, 14  85.0911  85.1004        49589028.0   49589028.0
# 2014-08-31         NaN      NaN      NaN               NaN          NaN
#
#                vwap
# date
# 2013-12-31  73.3833
# 2014-02-28  69.5702
# 2014-04-30  78.3607
# 2014-06-30  85.9819
# 2014-08-31      NaN

# %%
stocks.asfreq('W-MON').head() #OFFSET ALIASES
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2013-12-23  2.762500        0.000000          3.838  74.7447  74.8273
# 2013-12-30 -0.730286       -0.027310         -0.994  72.7034  73.4336
# 2014-01-06  0.386777       -0.045887          0.545  71.3149  71.6912
# 2014-01-13  0.365800       -0.060270          0.524  70.2398  71.1274
# 2014-01-20       NaN             NaN            NaN      NaN      NaN
#
#                  label      low     open  unadjustedVolume       volume  \
# date
# 2013-12-23  Dec 23, 13  73.7837  74.4707        17903833.0  125326831.0
# 2013-12-30  Dec 30, 13  72.4150  73.0888         9058246.0   63407722.0
# 2014-01-06   Jan 6, 14  69.9605  70.4653        14765593.0  103359151.0
# 2014-01-13  Jan 13, 14  69.4728  69.4767        13551549.0   94860843.0
# 2014-01-20         NaN      NaN      NaN               NaN          NaN
#
#                vwap
# date
# 2013-12-23  74.4027
# 2013-12-30  72.7190
# 2014-01-06  70.9303
# 2014-01-13  69.9468
# 2014-01-20      NaN

# %%
#USE ASFREQ using a frequency smaller than you have, its gonna add rows with NaN to follow your requirements
stocks.asfreq('D').head()
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2013-12-23  2.762500        0.000000          3.838  74.7447  74.8273
# 2013-12-24 -0.317288       -0.004244         -0.424  74.4275  74.9794
# 2013-12-25       NaN             NaN            NaN      NaN      NaN
# 2013-12-26 -0.494284       -0.010857         -0.664  73.9332  74.6674
# 2013-12-27 -0.499533       -0.017541         -0.676  73.4336  74.0000
#
#                  label      low     open  unadjustedVolume       volume  \
# date
# 2013-12-23  Dec 23, 13  73.7837  74.4707        17903833.0  125326831.0
# 2013-12-24  Dec 24, 13  74.2124  74.7185         5984105.0   41888735.0
# 2013-12-25         NaN      NaN      NaN               NaN          NaN
# 2013-12-26  Dec 26, 13  73.8645  74.4838         7286005.0   51002035.0
# 2013-12-27  Dec 27, 13  73.3563  73.9227         8067331.0   56471317.0
#
#                vwap
# date
# 2013-12-23  74.4027
# 2013-12-24  74.5717
# 2013-12-25      NaN
# 2013-12-26  74.1287
# 2013-12-27  73.5374

# %% [markdown]
# # 03. GROUPING BY TIME
#
# Whatever amount of time you want to group
# resample

# %%
stocks.head()
# Out:
#               change  changeOverTime  changePercent    close     high  \
# date
# 2013-12-23  2.762500        0.000000          3.838  74.7447  74.8273
# 2013-12-24 -0.317288       -0.004244         -0.424  74.4275  74.9794
# 2013-12-26 -0.494284       -0.010857         -0.664  73.9332  74.6674
# 2013-12-27 -0.499533       -0.017541         -0.676  73.4336  74.0000
# 2013-12-30 -0.730286       -0.027310         -0.994  72.7034  73.4336
#
#                  label      low     open  unadjustedVolume     volume     vwap
# date
# 2013-12-23  Dec 23, 13  73.7837  74.4707          17903833  125326831  74.4027
# 2013-12-24  Dec 24, 13  74.2124  74.7185           5984105   41888735  74.5717
# 2013-12-26  Dec 26, 13  73.8645  74.4838           7286005   51002035  74.1287
# 2013-12-27  Dec 27, 13  73.3563  73.9227           8067331   56471317  73.5374
# 2013-12-30  Dec 30, 13  72.4150  73.0888           9058246   63407722  72.7190

# %%
# grouping by Month, getting the max of the close value
stocks.resample('M').agg({'close':'max'}).head()
# Out:
#               close
# date
# 2013-12-31  74.7447
# 2014-01-31  73.0757
# 2014-02-28  72.0135
# 2014-03-31  71.8816
# 2014-04-30  78.3576

# %%
stocks.resample('Q', kind='period').agg({'close':'max'}).head()
# a period object in pandas mean a whole period of time
# Out:
#            close
# date
# 2013Q4   74.7447
# 2014Q1   73.0757
# 2014Q2   87.0870
# 2014Q3   95.9239
# 2014Q4  110.9819

# %%
stocks.resample('W', kind='period').agg({'close':'max'}).head()
# Out:
#                          close
# date
# 2013-12-23/2013-12-29  74.7447
# 2013-12-30/2014-01-05  73.5556
# 2014-01-06/2014-01-12  71.3149
# 2014-01-13/2014-01-19  73.0757
# 2014-01-20/2014-01-26  72.9210
