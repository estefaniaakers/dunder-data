# %% [markdown]
# # 4. Practicing Scikit-Learn Syntax
# Let's get good with Scikit-learn during this notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_columns = 100
# %matplotlib inline

heart = pd.read_csv('../data/heart.csv').dropna()
heart
# Out:
#      age     sex    chest_pain  rest_bp  chol  fbs  \
# 0     63    Male       typical      145   233    1
# 1     67    Male  asymptomatic      160   286    0
# 2     67    Male  asymptomatic      120   229    0
# 3     37    Male    nonanginal      130   250    0
# 4     41  Female    nontypical      130   204    0
# 5     56    Male    nontypical      120   236    0
# 6     62  Female  asymptomatic      140   268    0
# 7     57  Female  asymptomatic      120   354    0
# 8     63    Male  asymptomatic      130   254    0
# 9     53    Male  asymptomatic      140   203    1
# 10    57    Male  asymptomatic      140   192    0
# 11    56  Female    nontypical      140   294    0
# 12    56    Male    nonanginal      130   256    1
# 13    44    Male    nontypical      120   263    0
# 14    52    Male    nonanginal      172   199    1
# 15    57    Male    nonanginal      150   168    0
# 16    48    Male    nontypical      110   229    0
# 17    54    Male  asymptomatic      140   239    0
# 18    48  Female    nonanginal      130   275    0
# 19    49    Male    nontypical      130   266    0
# 20    64    Male       typical      110   211    0
# 21    58  Female       typical      150   283    1
# 22    58    Male    nontypical      120   284    0
# 23    58    Male    nonanginal      132   224    0
# 24    60    Male  asymptomatic      130   206    0
# 25    50  Female    nonanginal      120   219    0
# 26    58  Female    nonanginal      120   340    0
# 27    66  Female       typical      150   226    0
# 28    43    Male  asymptomatic      150   247    0
# 29    40    Male  asymptomatic      110   167    0
# ..   ...     ...           ...      ...   ...  ...
# 271   66    Male  asymptomatic      160   228    0
# 272   46    Male  asymptomatic      140   311    0
# 273   71  Female  asymptomatic      112   149    0
# 274   59    Male       typical      134   204    0
# 275   64    Male       typical      170   227    0
# 276   66  Female    nonanginal      146   278    0
# 277   39  Female    nonanginal      138   220    0
# 278   57    Male    nontypical      154   232    0
# 279   58  Female  asymptomatic      130   197    0
# 280   57    Male  asymptomatic      110   335    0
# 281   47    Male    nonanginal      130   253    0
# 282   55  Female  asymptomatic      128   205    0
# 283   35    Male    nontypical      122   192    0
# 284   61    Male  asymptomatic      148   203    0
# 285   58    Male  asymptomatic      114   318    0
# 286   58  Female  asymptomatic      170   225    1
# 288   56    Male    nontypical      130   221    0
# 289   56    Male    nontypical      120   240    0
# 290   67    Male    nonanginal      152   212    0
# 291   55  Female    nontypical      132   342    0
# 292   44    Male  asymptomatic      120   169    0
# 293   63    Male  asymptomatic      140   187    0
# 294   63  Female  asymptomatic      124   197    0
# 295   41    Male    nontypical      120   157    0
# 296   59    Male  asymptomatic      164   176    1
# 297   57  Female  asymptomatic      140   241    0
# 298   45    Male       typical      110   264    0
# 299   68    Male  asymptomatic      144   193    1
# 300   57    Male  asymptomatic      130   131    0
# 301   57  Female    nontypical      130   236    0
#
#                           rest_ecg  max_hr  exang  old_peak  slope   ca  \
# 0    left ventricular hypertrophy      150      0       2.3      3  0.0
# 301  left ventricular hypertrophy      174      0       0.0      2  1.0
#
#            thal  disease
# 0         fixed        0
# 1        normal        1
# 2    reversable        1
# 3        normal        0
# 4        normal        0
# 5        normal        0
# 6        normal        1
# 7        normal        0
# 8    reversable        1
# 9    reversable        1
# 10        fixed        0
# 11       normal        0
# 12        fixed        1
# 13   reversable        0
# 14   reversable        0
# 15       normal        0
# 16   reversable        1
# 17       normal        0
# 18       normal        0
# 19       normal        0
# 20       normal        0
# 21       normal        0
# 22       normal        1
# 23   reversable        1
# 24   reversable        1
# 25       normal        0
# 26       normal        0
# 27       normal        0
# 28       normal        0
# 29   reversable        1
# ..          ...      ...
# 271       fixed        0
# 272  reversable        1
# 273      normal        0
# 274      normal        1
# 275  reversable        0
# 276      normal        0
# 277      normal        0
# 278      normal        1
# 279      normal        0
# 280  reversable        1
# 281      normal        0
# 282  reversable        1
# 283      normal        0
# 284  reversable        1
# 285       fixed        1
# 286       fixed        1
# 288  reversable        0
# 289      normal        0
# 290  reversable        1
# 291      normal        0
# 292       fixed        1
# 293  reversable        1
# 294      normal        1
# 295      normal        0
# 296       fixed        1
# 297  reversable        1
# 298  reversable        1
# 299  reversable        1
# 300  reversable        1
# 301      normal        1
#
# [297 rows x 14 columns]

# %% [markdown]
# # Let's build many different models from different parts of the library slowly adding more features
# * Let's build decision trees, random forests, K-Nearest Neighbors and Support vector machines:
# * Predict, then Score, and write down your scores

# %% [markdown]
# # Scores
# * baseline - 54
# * logistic regression w/ max_hr - 67
# * knn w/ max_hr - 74
# * knn w/ 3 vars - 75

# %%
X = heart['max_hr'].values.reshape(-1, 1)
y = heart['disease'].values

# %%
X[:4]
# Out:
# array([[150],
#        [108],
#        [129],
#        [187]])

# %%
y[:4]
# Out:
# array([0, 1, 1, 0])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc = KNeighborsClassifier()

# %%
knc.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knc.score(X, y)
# Out:
# 0.7407407407407407

# %%
heart.head()
# Out:
#    age     sex    chest_pain  rest_bp  chol  fbs  \
# 0   63    Male       typical      145   233    1
# 1   67    Male  asymptomatic      160   286    0
# 2   67    Male  asymptomatic      120   229    0
# 3   37    Male    nonanginal      130   250    0
# 4   41  Female    nontypical      130   204    0
#
#                         rest_ecg  max_hr  exang  old_peak  slope   ca  \
# 0  left ventricular hypertrophy      150      0       2.3      3  0.0
# 1  left ventricular hypertrophy      108      1       1.5      2  3.0
# 2  left ventricular hypertrophy      129      1       2.6      2  2.0
# 3                         normal     187      0       3.5      3  0.0
# 4  left ventricular hypertrophy      172      0       1.4      1  0.0
#
#          thal  disease
# 0       fixed        0
# 1      normal        1
# 2  reversable        1
# 3      normal        0
# 4      normal        0

# %%
X = heart[['rest_bp', 'chol', 'max_hr']].values
X[:5]
# Out:
# array([[145, 233, 150],
#        [160, 286, 108],
#        [120, 229, 129],
#        [130, 250, 187],
#        [130, 204, 172]])

# %%
knc.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knc.score(X, y)
# Out:
# 0.7474747474747475

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dtc.score(X, y)
# Out:
# 1.0
