# %% [markdown]
# # The DataFrame
#
# ### Objectives
# After this lesson you should be able to...
# + Know a DataFrame is composed of **columns**, an **index** and **values**
# + The columns are formally a column index and have the same type as the index
# + Most analysis will take place in a DataFrame
# + Get descriptive statistics and metadata on DataFrames after import
# + Know the most common column datatypes
# + Change display settings in the notebook
# + Create a Series by selecting a single column of a DataFrame
# + Select a subset of columns from a DataFrame
# + Select rows and columns from a DataFrame by label and integer location with **`loc`** and **`.iloc`**
#
# ### Prepare for this lesson by...
# [ALWAYS READ THE DOCUMENTATION BEFORE A LESSON!](http://pandas.pydata.org/pandas-docs/stable/)
# + Read the [Intro to Data Structures](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe) - only the DataFrame section
# + Read all of the [Options and Settings](http://pandas.pydata.org/pandas-docs/stable/options.html) section
# + Read the section on [descriptive statistics](http://pandas.pydata.org/pandas-docs/stable/basics.html#descriptive-statistics)
#
# ### Introduction
#
# The DataFrame is the most common object you will be working with during your analysis and it is important for you to grasp all parts of it while using the correct terminology. There are three components to a DataFrame, the **index**, the **columns** and the **data**.
#
# ![dataframe anatomy](images/dataframe_anatomy.png)
#
# * The index labels the rows and the columns label the columns
# * An individual element of the index is an index label
# * An individual element of the columns is a column name
# * The index and the columns are always in bold font
# * Collectively the index and the columns are known as axes
# * pandas also refers to each axis by an integer. 0 for the index and 1 for the columns. This is borrowed directly from NumPy
# * The actual data is always in normal font
# * Data is also referred to as values
# * Missing values are displayed as NaN (not a number)
#
# Operations on DataFrames can be applied to all elements or by row or by column. The technical term **axis** refers to the horizontal and vertical components of the frame. The row axis is numbered 0 and the column axis is numbered 1, which is convention borrowed from NumPy where ndarrays can have limitless axes beginning with 0. The **`axis`** argument shows up in nearly all DataFrame methods, meaning you can choose to do an operation over the columns or the rows.
#
# Just as with Series, alignment of indexes silently takes place behind the scenes for DataFrames, so care needs to be taken when operating on 2 different DataFrames at the same time.

# %% [markdown]
# ### The Index Object
#
# Both the index and the columns are stored as pandas **`Index`** objects. There are many unique Index objects each having the word **`Index`** apart of them. All these index objects can be used to label the rows or columns. These pandas objects are **`Index, DatetimeIndex, CategoricalIndex, MultiIndex, IntervalIndex, RangeIndex, Int64Index, Float64Index, PeriodIndex, TimedeltaIndex, UInt64Index`** They all are very similar objects and have the same base functionality.
#
# ### MultiIndex DataFrames
# pandas allows for indexes to have more than one dimension. This is one of the more confusing aspects of pandas. MultiIndex DataFrames will be covered in a different notebook.

# %% [markdown]
# ### More info on the DataFrame
# When a Series is outputted, the data type of the values is printed to the screen. This doesn't happen with a DataFrame. Let's read in the employee data set and use the **`info`** method to get the data type and number of non-missing values for each column.
#
# The dataset was downloaded from the [city of Houston](http://data.ohouston.org/dataset/city-of-houston-current-employee-roster). Information for 2000 employees such as name, department, salary, race and others are provided.

# %%
import pandas as pd
import numpy as np

employee = pd.read_csv('data/employee.csv')
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# 2  2015-02-03  2015-02-03
# 3  1982-02-08  1991-05-25
# 4  1989-06-19  1994-10-22

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
# UNIQUE_ID            2000 non-null int64
# POSITION_TITLE       2000 non-null object
# DEPARTMENT           2000 non-null object
# BASE_SALARY          1886 non-null float64
# RACE                 1965 non-null object
# EMPLOYMENT_TYPE      2000 non-null object
# GENDER               2000 non-null object
# EMPLOYMENT_STATUS    2000 non-null object
# HIRE_DATE            2000 non-null object
# JOB_DATE             1997 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 156.3+ KB

# %% [markdown]
# ### Lots of info above
# + the object type (DataFrame)
# + the row index type (a RangeIndex)
# + the column names and their types ('object' is used for strings)
# + Number of non-missing values
# + A summary of the datatypes (8 object, 1 integer, 1 float)
# + the memory usage

# %% [markdown]
# ## DataFrame Dimensions
# + **`shape`** attribute - tuple of number of rows and columns
# + **`size`** attribute - total number of elements. rows times columns
# + **`len`** function - number of rows
# + **`ndim`** attribute - number of dimensions. Always two

# %%
employee.shape
# Out:
# (2000, 10)

# %%
employee.size
# Out:
# 20000

# %%
len(employee)
# Out:
# 2000

# %%
employee.ndim
# Out:
# 2

# %% [markdown]
# ### DataFrame by Pieces
# Each DataFrame has both a column **Index** and a row **Index**. The **values** (the actual data) are represented by a 2 dimensional NumPy array. Let's see those pieces.

# %%
# Row index is retrieved by .index
employee.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
# column index is just .columns
employee.columns
# Out:
# Index(['UNIQUE_ID', 'POSITION_TITLE', 'DEPARTMENT', 'BASE_SALARY', 'RACE',
#        'EMPLOYMENT_TYPE', 'GENDER', 'EMPLOYMENT_STATUS', 'HIRE_DATE',
#        'JOB_DATE'],
#       dtype='object')

# %%
# the values are a numpy array
employee.values
# Out:
# array([[0, 'ASSISTANT DIRECTOR (EX LVL)', 'Municipal Courts Department',
#         ..., 'Active', '2006-06-12', '2012-10-13'],
#        [1, 'LIBRARY ASSISTANT', 'Library', ..., 'Active', '2000-07-19',
#         '2010-09-18'],
#        [2, 'POLICE OFFICER', 'Houston Police Department-HPD', ...,
#         'Active', '2015-02-03', '2015-02-03'],
#        ...,
#        [1997, 'POLICE OFFICER', 'Houston Police Department-HPD', ...,
#         'Active', '2014-10-13', '2015-10-13'],
#        [1998, 'POLICE OFFICER', 'Houston Police Department-HPD', ...,
#         'Active', '2009-01-20', '2011-07-02'],
#        [1999, 'FIRE FIGHTER', 'Houston Fire Department (HFD)', ...,
#         'Active', '2009-01-12', '2010-07-12']], dtype=object)

# %% [markdown]
# ### Get summary statistics for numeric columns
# Basic summary statistics for numeric columns can be retrieved through the **`describe`** method. By default, **`describe`** ignores non-numeric columns.

# %%
employee.describe()
# Out:
#          UNIQUE_ID    BASE_SALARY
# count  2000.000000    1886.000000
# mean    999.500000   55767.931601
# std     577.494589   21693.706679
# min       0.000000   24960.000000
# 25%     499.750000   40170.000000
# 50%     999.500000   54461.000000
# 75%    1499.250000   66614.000000
# max    1999.000000  275000.000000

# %% [markdown]
# ## Different summary statistics for non-numeric columns
# Summary statistics for columns of specific data type may be specified with the **`include`** parameter.

# %%
# get summary statistics on only the 'objects'
employee.describe(include=['object'])
# Out:
#                POSITION_TITLE                     DEPARTMENT  \
# count                    2000                           2000
# unique                    330                             24
# top     SENIOR POLICE OFFICER  Houston Police Department-HPD
# freq                      220                            638
#
#                              RACE EMPLOYMENT_TYPE GENDER EMPLOYMENT_STATUS  \
# count                        1965            2000   2000              2000
# unique                          6               5      2                 2
# top     Black or African American       Full Time   Male            Active
# freq                          700            1954   1397              1991
#
#          HIRE_DATE    JOB_DATE
# count         2000        1997
# unique         999         947
# top     2016-03-28  2002-01-05
# freq            11          34

# %% [markdown]
# # Column Data Types
# Each column of data in your DataFrame has a specific data type. It is important to know what each data type is and how to refer to each one. You may refer to data types in pandas by either their numpy object name or their string name. Here is a complete list of [all numpy data types](https://docs.scipy.org/doc/numpy/user/basics.types.html).

# %% [markdown]
# <table>
# <thead>
# <td>Common Data Type Name</td>
# <td>NumPy/pandas Object Pandas</td>
# <td>String Name</td>
# <td>Notes</td>
# </thead>
# <tr>
# <td>Boolean</td>
# <td>np.bool</td>
# <td>bool</td>
# <td>Stored as a single byte</td>
# </tr>
# <tr>
# <td>Integer</td>
# <td>np.int</td>
# <td>int</td>
# <td>Defaulted to 64 bits. Also available are unsigned ints - np.uint</td>
# </tr>
# <tr>
# <td>Float</td>
# <td>np.float</td>
# <td>float</td>
# <td>Defaulted to 64 bit</td>
# </tr>
# <tr>
# <td>Object</td>
# <td>np.object</td>
# <td>O, object</td>
# <td>Typically strings but is a catchall for columns with multiple different types or other Python objects (tuples, lists, dicts, etc...)</td>
# </tr>
# <tr>
# <td>Datetime</td>
# <td>np.datetime64, pd.Timestamp</td>
# <td>datetime64 </td>
# <td>A specific moment in time with nanosecond precision</td>
# </tr>
# <tr>
# <td>Timedelta </td>
# <td>np.timedelta64, pd.Timedelta</td>
# <td>timedelta64 </td>
# <td>Represents an amount of time from days to nanoseconds</td>
#
# </tr>
# <tr>
# <td>Categorical </td>
# <td>pd.Categorical </td>
# <td>category </td>
# <td>Specific only to pandas. Useful
# for object columns with
# relatively few values</td>
# </tr>
# </table>

# %% [markdown]
# ### Using either the string or object name
# pandas allows the data type to be either in string form or be given by the exact object.

# %%
employee.describe(include=['float'])
# Out:
#          BASE_SALARY
# count    1886.000000
# mean    55767.931601
# std     21693.706679
# min     24960.000000
# 25%     40170.000000
# 50%     54461.000000
# 75%     66614.000000
# max    275000.000000

# %%
employee.describe(include=[np.float])
# Out:
#          BASE_SALARY
# count    1886.000000
# mean    55767.931601
# std     21693.706679
# min     24960.000000
# 25%     40170.000000
# 50%     54461.000000
# 75%     66614.000000
# max    275000.000000

# %% [markdown]
# #### Use a list of data types you would like descriptions on
# The default is to select all numeric columns - those that are either integer or float.

# %%
employee.describe(include=[np.float, 'int'])
# Out:
#          UNIQUE_ID    BASE_SALARY
# count  2000.000000    1886.000000
# mean    999.500000   55767.931601
# std     577.494589   21693.706679
# min       0.000000   24960.000000
# 25%     499.750000   40170.000000
# 50%     999.500000   54461.000000
# 75%    1499.250000   66614.000000
# max    1999.000000  275000.000000

# %% [markdown]
# ### Hidden Columns
# Let's load the movie dataset and inspect the head. Scroll to the right and you will notice that not all the columns are displayed to the screen.

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                                    ...           \
# movie_title                                        ...
# Avatar                                             ...
# Pirates of the Caribbean: At World's End           ...
# Spectre                                            ...
# The Dark Knight Rises                              ...
# Star Wars: Episode VII - The Force Awakens         ...
#
#                                            num_user_for_reviews  language  \
# movie_title
# Avatar                                                   3054.0   English
# Pirates of the Caribbean: At World's End                 1238.0   English
# Spectre                                                   994.0   English
# The Dark Knight Rises                                    2701.0   English
# Star Wars: Episode VII - The Force Awakens                  NaN       NaN
#
#                                             country content_rating  \
# movie_title
# Avatar                                          USA          PG-13
# Pirates of the Caribbean: At World's End        USA          PG-13
# Spectre                                          UK          PG-13
# The Dark Knight Rises                           USA          PG-13
# Star Wars: Episode VII - The Force Awakens      NaN            NaN
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Changing Display Settings
#
#  Pandas comes with default values for a couple dozen display settings to help control output. One of these parameters is the number of columns displayed to the screen. The options can all be found under **`pd.options.display`**. The all the display settings that can be changed below.

# %%
dir(pd.options.display)
# Out:
# ['chop_threshold',
#  'colheader_justify',
#  'column_space',
#  'date_dayfirst',
#  'date_yearfirst',
#  'encoding',
#  'expand_frame_repr',
#  'float_format',
#  'height',
#  'html',
#  'large_repr',
#  'latex',
#  'line_width',
#  'max_categories',
#  'max_columns',
#  'max_colwidth',
#  'max_info_columns',
#  'max_info_rows',
#  'max_rows',
#  'max_seq_items',
#  'memory_usage',
#  'mpl_style',
#  'multi_sparse',
#  'notebook_repr_html',
#  'pprint_nest_depth',
#  'precision',
#  'show_dimensions',
#  'unicode',
#  'width']

# %%
# Lets see the current settings
pd.options.display.max_columns
# Out:
# 20

# %% [markdown]
# Only 20 of the 30 columns are printed out in the notebook. We can adjust this setting easily by reassigning its value. More info on [pandas options settings](http://pandas.pydata.org/pandas-docs/stable/options.html).

# %%
# reassign max_columns
pd.options.display.max_columns = 40

# %%
# and now inspect the dataframe again
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                                actor_1_name  num_voted_users  \
# movie_title
# Avatar                                          CCH Pounder           886204
# Pirates of the Caribbean: At World's End        Johnny Depp           471220
# Spectre                                     Christoph Waltz           275868
# The Dark Knight Rises                             Tom Hardy          1144337
# Star Wars: Episode VII - The Force Awakens      Doug Walker                8
#
#                                             cast_total_facebook_likes  \
# movie_title
# Avatar                                                           4834
# Pirates of the Caribbean: At World's End                        48350
# Spectre                                                         11700
# The Dark Knight Rises                                          106759
# Star Wars: Episode VII - The Force Awakens                        143
#
#                                                     actor_3_name  \
# movie_title
# Avatar                                                 Wes Studi
# Pirates of the Caribbean: At World's End          Jack Davenport
# Spectre                                         Stephanie Sigman
# The Dark Knight Rises                       Joseph Gordon-Levitt
# Star Wars: Episode VII - The Force Awakens                   NaN
#
#                                             facenumber_in_poster  \
# movie_title
# Avatar                                                       0.0
# Pirates of the Caribbean: At World's End                     0.0
# Spectre                                                      1.0
# The Dark Knight Rises                                        0.0
# Star Wars: Episode VII - The Force Awakens                   0.0
#
#                                                                                 plot_keywords  \
# movie_title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End    goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                   bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                       deception|imprisonment|lawlessness|police offi...
# Star Wars: Episode VII - The Force Awakens                                                NaN
#
#                                                                               movie_imdb_link  \
# movie_title
# Avatar                                      http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# Pirates of the Caribbean: At World's End    http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# Spectre                                     http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# The Dark Knight Rises                       http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# Star Wars: Episode VII - The Force Awakens  http://www.imdb.com/title/tt5289954/?ref_=fn_t...
#
#                                             num_user_for_reviews language  \
# movie_title
# Avatar                                                    3054.0  English
# Pirates of the Caribbean: At World's End                  1238.0  English
# Spectre                                                    994.0  English
# The Dark Knight Rises                                     2701.0  English
# Star Wars: Episode VII - The Force Awakens                   NaN      NaN
#
#                                            country content_rating  \
# movie_title
# Avatar                                         USA          PG-13
# Pirates of the Caribbean: At World's End       USA          PG-13
# Spectre                                         UK          PG-13
# The Dark Knight Rises                          USA          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN            NaN
#
#                                                  budget  title_year  \
# movie_title
# Avatar                                      237000000.0      2009.0
# Pirates of the Caribbean: At World's End    300000000.0      2007.0
# Spectre                                     245000000.0      2015.0
# The Dark Knight Rises                       250000000.0      2012.0
# Star Wars: Episode VII - The Force Awakens          NaN         NaN
#
#                                             actor_2_facebook_likes  \
# movie_title
# Avatar                                                       936.0
# Pirates of the Caribbean: At World's End                    5000.0
# Spectre                                                      393.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                    12.0
#
#                                             imdb_score  aspect_ratio  \
# movie_title
# Avatar                                             7.9          1.78
# Pirates of the Caribbean: At World's End           7.1          2.35
# Spectre                                            6.8          2.35
# The Dark Knight Rises                              8.5          2.35
# Star Wars: Episode VII - The Force Awakens         7.1           NaN
#
#                                             movie_facebook_likes
# movie_title
# Avatar                                                     33000
# Pirates of the Caribbean: At World's End                       0
# Spectre                                                    85000
# The Dark Knight Rises                                     164000
# Star Wars: Episode VII - The Force Awakens                     0

# %% [markdown]
# ### Transpose a DataFrame
# Occasionally its useful to transpose a DataFrame - swap the columns and the rows. In this case, the output will be much more readable. Use the **`.T`** attribute.

# %%
employee.describe(include=['object']).T
# Out:
#                   count unique                            top  freq
# POSITION_TITLE     2000    330          SENIOR POLICE OFFICER   220
# DEPARTMENT         2000     24  Houston Police Department-HPD   638
# RACE               1965      6      Black or African American   700
# EMPLOYMENT_TYPE    2000      5                      Full Time  1954
# GENDER             2000      2                           Male  1397
# EMPLOYMENT_STATUS  2000      2                         Active  1991
# HIRE_DATE          2000    999                     2016-03-28    11
# JOB_DATE           1997    947                     2002-01-05    34

# %% [markdown]
# ### Always know your Index
# Its important to be aware of your (row) index in a DataFrame. The column index is usually obvious as it's just the column names.

# %%
# when the read_csv is not given an index, the default is make the index integers starting from 0
employee.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %% [markdown]
# ### RangeIndex
# A **`RangeIndex`** is the default index pandas gives you if you don't explicitly set one. It is similar to the built-in **`range`** object. It is a delayed object, meaning that only the minimal amount of information needed to describe it fully is stored in memory, that being the **start**, **stop** and **step**. Its mainly used to save space as there is no need to store all the values.
#
# ### Underlying NumPy Array
# Under all indexes and the data lies a numpy array. You can use the values index attribute to return the array.

# %%
# See the values of a RangeIndex
employee.index.values
# Out:
# array([   0,    1,    2, ..., 1997, 1998, 1999])

# %% [markdown]
# ### Columns are an Index Object
# The columns and the index must be one of the pandas Index objects. By default, the columns will be of type **`pd.Index`**. You can get the underlying NumPy array by again using the values index attribute.

# %%
employee.columns
# Out:
# Index(['UNIQUE_ID', 'POSITION_TITLE', 'DEPARTMENT', 'BASE_SALARY', 'RACE',
#        'EMPLOYMENT_TYPE', 'GENDER', 'EMPLOYMENT_STATUS', 'HIRE_DATE',
#        'JOB_DATE'],
#       dtype='object')

# %%
employee.columns.values
# Out:
# array(['UNIQUE_ID', 'POSITION_TITLE', 'DEPARTMENT', 'BASE_SALARY', 'RACE',
#        'EMPLOYMENT_TYPE', 'GENDER', 'EMPLOYMENT_STATUS', 'HIRE_DATE',
#        'JOB_DATE'], dtype=object)

# %% [markdown]
# ## The [ ] is completely different for DataFrames than for Series
# The bracket's primary use is to retrieve a column(s) from a DataFrame. Simply write the name of the column into the brackets and a Series will be returned. This behavior for the [ ] is completely different for Series where it is used to retrieve value(s) by the index.

# %%
employee['DEPARTMENT'].head(10)
# Out:
# 0       Municipal Courts Department
# 1                           Library
# 2     Houston Police Department-HPD
# 3     Houston Fire Department (HFD)
# 4       General Services Department
# 5     Houston Police Department-HPD
# 6    Public Works & Engineering-PWE
# 7      Houston Airport System (HAS)
# 8    Public Works & Engineering-PWE
# 9      Houston Airport System (HAS)
# Name: DEPARTMENT, dtype: object

# %% [markdown]
# ### Use a list to access multiple columns

# %%
# get three columns - put names in a list
# Returns a DataFrame

employee[['DEPARTMENT', 'GENDER', 'RACE']].head()
# Out:
#                       DEPARTMENT  GENDER             RACE
# 0    Municipal Courts Department  Female  Hispanic/Latino
# 1                        Library  Female  Hispanic/Latino
# 2  Houston Police Department-HPD    Male            White
# 3  Houston Fire Department (HFD)    Male            White
# 4    General Services Department    Male            White

# %% [markdown]
# ### Use a one item list to select a single column as a DataFrame

# %%
# If you want to return a single column as a dataframe use a list with one column name
employee[['DEPARTMENT']].head(10)
# Out:
#                        DEPARTMENT
# 0     Municipal Courts Department
# 1                         Library
# 2   Houston Police Department-HPD
# 3   Houston Fire Department (HFD)
# 4     General Services Department
# 5   Houston Police Department-HPD
# 6  Public Works & Engineering-PWE
# 7    Houston Airport System (HAS)
# 8  Public Works & Engineering-PWE
# 9    Houston Airport System (HAS)

# %% [markdown]
# ### You have a Series when you access a single column
# It's important to know that when you use the **`[ ]`** operator for a DataFrame and pass a single column name into it, you are back to having a Series. All the Series functions will work as before.

# %%
# use the same Series functions as before

# use max series method
employee['BASE_SALARY'].max()
# Out:
# 275000.0

# %%
employee['BASE_SALARY'].mean()
# Out:
# 55767.93160127253

# %%
# find the standard deviation in salaries
employee['BASE_SALARY'].std()
# Out:
# 21693.706679449504

# %% [markdown]
# ## Selecting data by integer location or by index label
# DataFrames use the **`.iloc`** and **`.loc`** indexers to select data. We will demonstrate the usage of the indexers by first making selections based upon rows then by columns and finally by both rows and columns simultaneously.
#
# ### Using .iloc for DataFrames
# **`.iloc`** accepts integers, slices and lists of integers and returns all rows with matching those integer locations.
#
# #### Single integer with .iloc
# A single scalar returns a Series with columns now in the index.

# %%
movie.iloc[10].head()
# Out:
# color                            Color
# director_name              Zack Snyder
# num_critic_for_reviews             673
# duration                           183
# director_facebook_likes              0
# Name: Batman v Superman: Dawn of Justice, dtype: object

# %% [markdown]
# #### Slicing with .iloc

# %%
movie.iloc[10:15]
# Out:
#                                             color   director_name  \
# movie_title
# Batman v Superman: Dawn of Justice          Color     Zack Snyder
# Superman Returns                            Color    Bryan Singer
# Quantum of Solace                           Color    Marc Forster
# Pirates of the Caribbean: Dead Man's Chest  Color  Gore Verbinski
# The Lone Ranger                             Color  Gore Verbinski
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Batman v Superman: Dawn of Justice                           673.0     183.0
# Superman Returns                                             434.0     169.0
# Quantum of Solace                                            403.0     106.0
# Pirates of the Caribbean: Dead Man's Chest                   313.0     151.0
# The Lone Ranger                                              450.0     150.0
#
#                                             director_facebook_likes  \
# movie_title
# Batman v Superman: Dawn of Justice                              0.0
# Superman Returns                                                0.0
# Quantum of Solace                                             395.0
# Pirates of the Caribbean: Dead Man's Chest                    563.0
# The Lone Ranger                                               563.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Batman v Superman: Dawn of Justice                          2000.0
# Superman Returns                                             903.0
# Quantum of Solace                                            393.0
# Pirates of the Caribbean: Dead Man's Chest                  1000.0
# The Lone Ranger                                             1000.0
#
#                                                actor_2_name  \
# movie_title
# Batman v Superman: Dawn of Justice             Lauren Cohan
# Superman Returns                              Marlon Brando
# Quantum of Solace                           Mathieu Amalric
# Pirates of the Caribbean: Dead Man's Chest    Orlando Bloom
# The Lone Ranger                                 Ruth Wilson
#
#                                             actor_1_facebook_likes  \
# movie_title
# Batman v Superman: Dawn of Justice                         15000.0
# Superman Returns                                           18000.0
# Quantum of Solace                                            451.0
# Pirates of the Caribbean: Dead Man's Chest                 40000.0
# The Lone Ranger                                            40000.0
#
#                                                   gross  \
# movie_title
# Batman v Superman: Dawn of Justice          330249062.0
# Superman Returns                            200069408.0
# Quantum of Solace                           168368427.0
# Pirates of the Caribbean: Dead Man's Chest  423032628.0
# The Lone Ranger                              89289910.0
#
#                                                               genres  \
# movie_title
# Batman v Superman: Dawn of Justice           Action|Adventure|Sci-Fi
# Superman Returns                             Action|Adventure|Sci-Fi
# Quantum of Solace                                   Action|Adventure
# Pirates of the Caribbean: Dead Man's Chest  Action|Adventure|Fantasy
# The Lone Ranger                             Action|Adventure|Western
#
#                                                   actor_1_name  \
# movie_title
# Batman v Superman: Dawn of Justice                Henry Cavill
# Superman Returns                                  Kevin Spacey
# Quantum of Solace                           Giancarlo Giannini
# Pirates of the Caribbean: Dead Man's Chest         Johnny Depp
# The Lone Ranger                                    Johnny Depp
#
#                                             num_voted_users  \
# movie_title
# Batman v Superman: Dawn of Justice                   371639
# Superman Returns                                     240396
# Quantum of Solace                                    330784
# Pirates of the Caribbean: Dead Man's Chest           522040
# The Lone Ranger                                      181792
#
#                                             cast_total_facebook_likes  \
# movie_title
# Batman v Superman: Dawn of Justice                              24450
# Superman Returns                                                29991
# Quantum of Solace                                                2023
# Pirates of the Caribbean: Dead Man's Chest                      48486
# The Lone Ranger                                                 45757
#
#                                               actor_3_name  \
# movie_title
# Batman v Superman: Dawn of Justice          Alan D. Purwin
# Superman Returns                            Frank Langella
# Quantum of Solace                             Rory Kinnear
# Pirates of the Caribbean: Dead Man's Chest  Jack Davenport
# The Lone Ranger                              Tom Wilkinson
#
#                                             facenumber_in_poster  \
# movie_title
# Batman v Superman: Dawn of Justice                           0.0
# Superman Returns                                             0.0
# Quantum of Solace                                            1.0
# Pirates of the Caribbean: Dead Man's Chest                   2.0
# The Lone Ranger                                              1.0
#
#                                                                                 plot_keywords  \
# movie_title
# Batman v Superman: Dawn of Justice          based on comic book|batman|sequel to a reboot|...
# Superman Returns                            crystal|epic|lex luthor|lois lane|return to earth
# Quantum of Solace                           action hero|attempted rape|bond girl|official ...
# Pirates of the Caribbean: Dead Man's Chest  box office hit|giant squid|heart|liar's dice|m...
# The Lone Ranger                                         horse|outlaw|texas|texas ranger|train
#
#                                                                               movie_imdb_link  \
# movie_title
# Batman v Superman: Dawn of Justice          http://www.imdb.com/title/tt2975590/?ref_=fn_t...
# Superman Returns                            http://www.imdb.com/title/tt0348150/?ref_=fn_t...
# Quantum of Solace                           http://www.imdb.com/title/tt0830515/?ref_=fn_t...
# Pirates of the Caribbean: Dead Man's Chest  http://www.imdb.com/title/tt0383574/?ref_=fn_t...
# The Lone Ranger                             http://www.imdb.com/title/tt1210819/?ref_=fn_t...
#
#                                             num_user_for_reviews language  \
# movie_title
# Batman v Superman: Dawn of Justice                        3018.0  English
# Superman Returns                                          2367.0  English
# Quantum of Solace                                         1243.0  English
# Pirates of the Caribbean: Dead Man's Chest                1832.0  English
# The Lone Ranger                                            711.0  English
#
#                                            country content_rating  \
# movie_title
# Batman v Superman: Dawn of Justice             USA          PG-13
# Superman Returns                               USA          PG-13
# Quantum of Solace                               UK          PG-13
# Pirates of the Caribbean: Dead Man's Chest     USA          PG-13
# The Lone Ranger                                USA          PG-13
#
#                                                  budget  title_year  \
# movie_title
# Batman v Superman: Dawn of Justice          250000000.0      2016.0
# Superman Returns                            209000000.0      2006.0
# Quantum of Solace                           200000000.0      2008.0
# Pirates of the Caribbean: Dead Man's Chest  225000000.0      2006.0
# The Lone Ranger                             215000000.0      2013.0
#
#                                             actor_2_facebook_likes  \
# movie_title
# Batman v Superman: Dawn of Justice                          4000.0
# Superman Returns                                           10000.0
# Quantum of Solace                                            412.0
# Pirates of the Caribbean: Dead Man's Chest                  5000.0
# The Lone Ranger                                             2000.0
#
#                                             imdb_score  aspect_ratio  \
# movie_title
# Batman v Superman: Dawn of Justice                 6.9          2.35
# Superman Returns                                   6.1          2.35
# Quantum of Solace                                  6.7          2.35
# Pirates of the Caribbean: Dead Man's Chest         7.3          2.35
# The Lone Ranger                                    6.5          2.35
#
#                                             movie_facebook_likes
# movie_title
# Batman v Superman: Dawn of Justice                        197000
# Superman Returns                                               0
# Quantum of Solace                                              0
# Pirates of the Caribbean: Dead Man's Chest                  5000
# The Lone Ranger                                            48000

# %%
movie.iloc[100:300:50]
# Out:
#                                        color    director_name  \
# movie_title
# The Fast and the Furious               Color        Rob Cohen
# Armageddon                             Color      Michael Bay
# Harry Potter and the Sorcerer's Stone  Color   Chris Columbus
# The Patriot                            Color  Roland Emmerich
#
#                                        num_critic_for_reviews  duration  \
# movie_title
# The Fast and the Furious                                187.0     106.0
# Armageddon                                              167.0     153.0
# Harry Potter and the Sorcerer's Stone                   258.0     159.0
# The Patriot                                             192.0     142.0
#
#                                        director_facebook_likes  \
# movie_title
# The Fast and the Furious                                 357.0
# Armageddon                                                 0.0
# Harry Potter and the Sorcerer's Stone                      0.0
# The Patriot                                              776.0
#
#                                        actor_3_facebook_likes   actor_2_name  \
# movie_title
# The Fast and the Furious                               4000.0     Vin Diesel
# Armageddon                                              537.0  Steve Buscemi
# Harry Potter and the Sorcerer's Stone                   645.0     Fiona Shaw
# The Patriot                                            1000.0   Adam Baldwin
#
#                                        actor_1_facebook_likes        gross  \
# movie_title
# The Fast and the Furious                              23000.0  144512310.0
# Armageddon                                            13000.0  201573391.0
# Harry Potter and the Sorcerer's Stone                 11000.0  317557891.0
# The Patriot                                           13000.0  113330342.0
#
#                                                                  genres  \
# movie_title
# The Fast and the Furious                          Action|Crime|Thriller
# Armageddon                             Action|Adventure|Sci-Fi|Thriller
# Harry Potter and the Sorcerer's Stone          Adventure|Family|Fantasy
# The Patriot                                    Action|Drama|History|War
#
#                                            actor_1_name  num_voted_users  \
# movie_title
# The Fast and the Furious                    Paul Walker           272223
# Armageddon                                 Bruce Willis           322395
# Harry Potter and the Sorcerer's Stone  Daniel Radcliffe           444683
# The Patriot                                Heath Ledger           207613
#
#                                        cast_total_facebook_likes  \
# movie_title
# The Fast and the Furious                                   45327
# Armageddon                                                 26029
# Harry Potter and the Sorcerer's Stone                      13191
# The Patriot                                                19454
#
#                                            actor_3_name  facenumber_in_poster  \
# movie_title
# The Fast and the Furious               Jordana Brewster                   2.0
# Armageddon                                  Will Patton                   0.0
# Harry Potter and the Sorcerer's Stone      Verne Troyer                   4.0
# The Patriot                               Tom Wilkinson                   1.0
#
#                                                                            plot_keywords  \
# movie_title
# The Fast and the Furious               eighteen wheeler|illegal street racing|truck|t...
# Armageddon                                 asteroid|astronaut|bomb|meteorite|outer space
# Harry Potter and the Sorcerer's Stone  based on novel|birthday|evil wizard|quidditch|...
# The Patriot                             american revolution|british|french|hero|standoff
#
#                                                                          movie_imdb_link  \
# movie_title
# The Fast and the Furious               http://www.imdb.com/title/tt0232500/?ref_=fn_t...
# Armageddon                             http://www.imdb.com/title/tt0120591/?ref_=fn_t...
# Harry Potter and the Sorcerer's Stone  http://www.imdb.com/title/tt0241527/?ref_=fn_t...
# The Patriot                            http://www.imdb.com/title/tt0187393/?ref_=fn_t...
#
#                                        num_user_for_reviews language country  \
# movie_title
# The Fast and the Furious                              988.0  English     USA
# Armageddon                                           1171.0  English     USA
# Harry Potter and the Sorcerer's Stone                1571.0  English      UK
# The Patriot                                          1144.0  English     USA
#
#                                       content_rating       budget  title_year  \
# movie_title
# The Fast and the Furious                       PG-13   38000000.0      2001.0
# Armageddon                                     PG-13  140000000.0      1998.0
# Harry Potter and the Sorcerer's Stone             PG  125000000.0      2001.0
# The Patriot                                        R  110000000.0      2000.0
#
#                                        actor_2_facebook_likes  imdb_score  \
# movie_title
# The Fast and the Furious                              14000.0         6.7
# Armageddon                                            12000.0         6.6
# Harry Potter and the Sorcerer's Stone                   687.0         7.5
# The Patriot                                            2000.0         7.1
#
#                                        aspect_ratio  movie_facebook_likes
# movie_title
# The Fast and the Furious                       2.35                 14000
# Armageddon                                     2.35                 11000
# Harry Potter and the Sorcerer's Stone          2.35                 16000
# The Patriot                                    2.35                  4000

# %% [markdown]
# #### Lists of integers with .iloc

# %%
movie.iloc[[1,100,1000]]
# Out:
#                                           color   director_name  \
# movie_title
# Pirates of the Caribbean: At World's End  Color  Gore Verbinski
# The Fast and the Furious                  Color       Rob Cohen
# The Life Aquatic with Steve Zissou        Color    Wes Anderson
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Pirates of the Caribbean: At World's End                   302.0     169.0
# The Fast and the Furious                                   187.0     106.0
# The Life Aquatic with Steve Zissou                         259.0     119.0
#
#                                           director_facebook_likes  \
# movie_title
# Pirates of the Caribbean: At World's End                    563.0
# The Fast and the Furious                                    357.0
# The Life Aquatic with Steve Zissou                            0.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# Pirates of the Caribbean: At World's End                  1000.0
# The Fast and the Furious                                  4000.0
# The Life Aquatic with Steve Zissou                         639.0
#
#                                              actor_2_name  \
# movie_title
# Pirates of the Caribbean: At World's End    Orlando Bloom
# The Fast and the Furious                       Vin Diesel
# The Life Aquatic with Steve Zissou        Anjelica Huston
#
#                                           actor_1_facebook_likes        gross  \
# movie_title
# Pirates of the Caribbean: At World's End                 40000.0  309404152.0
# The Fast and the Furious                                 23000.0  144512310.0
# The Life Aquatic with Steve Zissou                       13000.0   24006726.0
#
#                                                             genres  \
# movie_title
# Pirates of the Caribbean: At World's End  Action|Adventure|Fantasy
# The Fast and the Furious                     Action|Crime|Thriller
# The Life Aquatic with Steve Zissou          Adventure|Comedy|Drama
#
#                                          actor_1_name  num_voted_users  \
# movie_title
# Pirates of the Caribbean: At World's End  Johnny Depp           471220
# The Fast and the Furious                  Paul Walker           272223
# The Life Aquatic with Steve Zissou        Bill Murray           139535
#
#                                           cast_total_facebook_likes  \
# movie_title
# Pirates of the Caribbean: At World's End                      48350
# The Fast and the Furious                                      45327
# The Life Aquatic with Steve Zissou                            15757
#
#                                                  actor_3_name  \
# movie_title
# Pirates of the Caribbean: At World's End       Jack Davenport
# The Fast and the Furious                     Jordana Brewster
# The Life Aquatic with Steve Zissou        Matthew Gray Gubler
#
#                                           facenumber_in_poster  \
# movie_title
# Pirates of the Caribbean: At World's End                   0.0
# The Fast and the Furious                                   2.0
# The Life Aquatic with Steve Zissou                         8.0
#
#                                                                               plot_keywords  \
# movie_title
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# The Fast and the Furious                  eighteen wheeler|illegal street racing|truck|t...
# The Life Aquatic with Steve Zissou                  expedition|oceanographer|sea|shark|team
#
#                                                                             movie_imdb_link  \
# movie_title
# Pirates of the Caribbean: At World's End  http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# The Fast and the Furious                  http://www.imdb.com/title/tt0232500/?ref_=fn_t...
# The Life Aquatic with Steve Zissou        http://www.imdb.com/title/tt0362270/?ref_=fn_t...
#
#                                           num_user_for_reviews language  \
# movie_title
# Pirates of the Caribbean: At World's End                1238.0  English
# The Fast and the Furious                                 988.0  English
# The Life Aquatic with Steve Zissou                       632.0  English
#
#                                          country content_rating       budget  \
# movie_title
# Pirates of the Caribbean: At World's End     USA          PG-13  300000000.0
# The Fast and the Furious                     USA          PG-13   38000000.0
# The Life Aquatic with Steve Zissou           USA              R   50000000.0
#
#                                           title_year  actor_2_facebook_likes  \
# movie_title
# Pirates of the Caribbean: At World's End      2007.0                  5000.0
# The Fast and the Furious                      2001.0                 14000.0
# The Life Aquatic with Steve Zissou            2004.0                  1000.0
#
#                                           imdb_score  aspect_ratio  \
# movie_title
# Pirates of the Caribbean: At World's End         7.1          2.35
# The Fast and the Furious                         6.7          2.35
# The Life Aquatic with Steve Zissou               7.3          2.35
#
#                                           movie_facebook_likes
# movie_title
# Pirates of the Caribbean: At World's End                     0
# The Fast and the Furious                                 14000
# The Life Aquatic with Steve Zissou                           0

# %%
# single item list returns a dataframe
movie.iloc[[10]]
# Out:
#                                     color director_name  \
# movie_title
# Batman v Superman: Dawn of Justice  Color   Zack Snyder
#
#                                     num_critic_for_reviews  duration  \
# movie_title
# Batman v Superman: Dawn of Justice                   673.0     183.0
#
#                                     director_facebook_likes  \
# movie_title
# Batman v Superman: Dawn of Justice                      0.0
#
#                                     actor_3_facebook_likes  actor_2_name  \
# movie_title
# Batman v Superman: Dawn of Justice                  2000.0  Lauren Cohan
#
#                                     actor_1_facebook_likes        gross  \
# movie_title
# Batman v Superman: Dawn of Justice                 15000.0  330249062.0
#
#                                                      genres  actor_1_name  \
# movie_title
# Batman v Superman: Dawn of Justice  Action|Adventure|Sci-Fi  Henry Cavill
#
#                                     num_voted_users  \
# movie_title
# Batman v Superman: Dawn of Justice           371639
#
#                                     cast_total_facebook_likes    actor_3_name  \
# movie_title
# Batman v Superman: Dawn of Justice                      24450  Alan D. Purwin
#
#                                     facenumber_in_poster  \
# movie_title
# Batman v Superman: Dawn of Justice                   0.0
#
#                                                                         plot_keywords  \
# movie_title
# Batman v Superman: Dawn of Justice  based on comic book|batman|sequel to a reboot|...
#
#                                                                       movie_imdb_link  \
# movie_title
# Batman v Superman: Dawn of Justice  http://www.imdb.com/title/tt2975590/?ref_=fn_t...
#
#                                     num_user_for_reviews language country  \
# movie_title
# Batman v Superman: Dawn of Justice                3018.0  English     USA
#
#                                    content_rating       budget  title_year  \
# movie_title
# Batman v Superman: Dawn of Justice          PG-13  250000000.0      2016.0
#
#                                     actor_2_facebook_likes  imdb_score  \
# movie_title
# Batman v Superman: Dawn of Justice                  4000.0         6.9
#
#                                     aspect_ratio  movie_facebook_likes
# movie_title
# Batman v Superman: Dawn of Justice          2.35                197000

# %% [markdown]
# ### Using .loc
# **`.loc`** only works with index labels, so you must know the exact string (or integer) in the label.
#
# #### Single String with .loc

# %%
movie.loc['The Fast and the Furious'].head()
# Out:
# color                          Color
# director_name              Rob Cohen
# num_critic_for_reviews           187
# duration                         106
# director_facebook_likes          357
# Name: The Fast and the Furious, dtype: object

# %% [markdown]
# #### Slicing with .loc

# %%
movie.index[200]
# Out:
# "Harry Potter and the Sorcerer's Stone"

# %%
movie.index[600]
# Out:
# 'Wall Street: Money Never Sleeps'

# %%
movie.loc["Harry Potter and the Sorcerer's Stone":'Wall Street: Money Never Sleeps'].head()
# Out:
#                                                     color     director_name  \
# movie_title
# Harry Potter and the Sorcerer's Stone               Color    Chris Columbus
# R.I.P.D.                                            Color  Robert Schwentke
# Pirates of the Caribbean: The Curse of the Blac...  Color    Gore Verbinski
# Harry Potter and the Deathly Hallows: Part I        Color        Matt Birch
# The Hunger Games: Mockingjay - Part 1               Color  Francis Lawrence
#
#                                                     num_critic_for_reviews  \
# movie_title
# Harry Potter and the Sorcerer's Stone                                258.0
# R.I.P.D.                                                             208.0
# Pirates of the Caribbean: The Curse of the Blac...                   271.0
# Harry Potter and the Deathly Hallows: Part I                           4.0
# The Hunger Games: Mockingjay - Part 1                                403.0
#
#                                                     duration  \
# movie_title
# Harry Potter and the Sorcerer's Stone                  159.0
# R.I.P.D.                                                96.0
# Pirates of the Caribbean: The Curse of the Blac...     143.0
# Harry Potter and the Deathly Hallows: Part I             NaN
# The Hunger Games: Mockingjay - Part 1                  123.0
#
#                                                     director_facebook_likes  \
# movie_title
# Harry Potter and the Sorcerer's Stone                                   0.0
# R.I.P.D.                                                              124.0
# Pirates of the Caribbean: The Curse of the Blac...                    563.0
# Harry Potter and the Deathly Hallows: Part I                            0.0
# The Hunger Games: Mockingjay - Part 1                                 508.0
#
#                                                     actor_3_facebook_likes  \
# movie_title
# Harry Potter and the Sorcerer's Stone                                645.0
# R.I.P.D.                                                            1000.0
# Pirates of the Caribbean: The Curse of the Blac...                  1000.0
# Harry Potter and the Deathly Hallows: Part I                        1000.0
# The Hunger Games: Mockingjay - Part 1                              14000.0
#
#                                                               actor_2_name  \
# movie_title
# Harry Potter and the Sorcerer's Stone                           Fiona Shaw
# R.I.P.D.                                                      Jeff Bridges
# Pirates of the Caribbean: The Curse of the Blac...           Orlando Bloom
# Harry Potter and the Deathly Hallows: Part I                    Toby Jones
# The Hunger Games: Mockingjay - Part 1               Philip Seymour Hoffman
#
#                                                     actor_1_facebook_likes  \
# movie_title
# Harry Potter and the Sorcerer's Stone                              11000.0
# R.I.P.D.                                                           16000.0
# Pirates of the Caribbean: The Curse of the Blac...                 40000.0
# Harry Potter and the Deathly Hallows: Part I                       10000.0
# The Hunger Games: Mockingjay - Part 1                              34000.0
#
#                                                           gross  \
# movie_title
# Harry Potter and the Sorcerer's Stone               317557891.0
# R.I.P.D.                                             33592415.0
# Pirates of the Caribbean: The Curse of the Blac...  305388685.0
# Harry Potter and the Deathly Hallows: Part I                NaN
# The Hunger Games: Mockingjay - Part 1               337103873.0
#
#                                                                        genres  \
# movie_title
# Harry Potter and the Sorcerer's Stone                Adventure|Family|Fantasy
# R.I.P.D.                                                Action|Comedy|Fantasy
# Pirates of the Caribbean: The Curse of the Blac...   Action|Adventure|Fantasy
# Harry Potter and the Deathly Hallows: Part I                          Fantasy
# The Hunger Games: Mockingjay - Part 1               Adventure|Sci-Fi|Thriller
#
#                                                          actor_1_name  \
# movie_title
# Harry Potter and the Sorcerer's Stone                Daniel Radcliffe
# R.I.P.D.                                                Ryan Reynolds
# Pirates of the Caribbean: The Curse of the Blac...        Johnny Depp
# Harry Potter and the Deathly Hallows: Part I             Rupert Grint
# The Hunger Games: Mockingjay - Part 1               Jennifer Lawrence
#
#                                                     num_voted_users  \
# movie_title
# Harry Potter and the Sorcerer's Stone                        444683
# R.I.P.D.                                                      91640
# Pirates of the Caribbean: The Curse of the Blac...           809474
# Harry Potter and the Deathly Hallows: Part I                    252
# The Hunger Games: Mockingjay - Part 1                        305008
#
#                                                     cast_total_facebook_likes  \
# movie_title
# Harry Potter and the Sorcerer's Stone                                   13191
# R.I.P.D.                                                                31549
# Pirates of the Caribbean: The Curse of the Blac...                      48184
# Harry Potter and the Deathly Hallows: Part I                            14719
# The Hunger Games: Mockingjay - Part 1                                   81385
#
#                                                          actor_3_name  \
# movie_title
# Harry Potter and the Sorcerer's Stone                    Verne Troyer
# R.I.P.D.                                            Stephanie Szostak
# Pirates of the Caribbean: The Curse of the Blac...     Jack Davenport
# Harry Potter and the Deathly Hallows: Part I             Alfred Enoch
# The Hunger Games: Mockingjay - Part 1                 Josh Hutcherson
#
#                                                     facenumber_in_poster  \
# movie_title
# Harry Potter and the Sorcerer's Stone                                4.0
# R.I.P.D.                                                             2.0
# Pirates of the Caribbean: The Curse of the Blac...                   3.0
# Harry Potter and the Deathly Hallows: Part I                         1.0
# The Hunger Games: Mockingjay - Part 1                                1.0
#
#                                                                                         plot_keywords  \
# movie_title
# Harry Potter and the Sorcerer's Stone               based on novel|birthday|evil wizard|quidditch|...
# R.I.P.D.                                                       drug dealer|gold|partner|police|undead
# Pirates of the Caribbean: The Curse of the Blac...             caribbean|curse|governor|pirate|undead
# Harry Potter and the Deathly Hallows: Part I                                                      NaN
# The Hunger Games: Mockingjay - Part 1               based on young adult novel|manipulation|rebell...
#
#                                                                                       movie_imdb_link  \
# movie_title
# Harry Potter and the Sorcerer's Stone               http://www.imdb.com/title/tt0241527/?ref_=fn_t...
# R.I.P.D.                                            http://www.imdb.com/title/tt0790736/?ref_=fn_t...
# Pirates of the Caribbean: The Curse of the Blac...  http://www.imdb.com/title/tt0325980/?ref_=fn_t...
# Harry Potter and the Deathly Hallows: Part I        http://www.imdb.com/title/tt1571403/?ref_=fn_t...
# The Hunger Games: Mockingjay - Part 1               http://www.imdb.com/title/tt1951265/?ref_=fn_t...
#
#                                                     num_user_for_reviews  \
# movie_title
# Harry Potter and the Sorcerer's Stone                             1571.0
# R.I.P.D.                                                           210.0
# Pirates of the Caribbean: The Curse of the Blac...                2113.0
# Harry Potter and the Deathly Hallows: Part I                         2.0
# The Hunger Games: Mockingjay - Part 1                              591.0
#
#                                                    language country  \
# movie_title
# Harry Potter and the Sorcerer's Stone               English      UK
# R.I.P.D.                                            English     USA
# Pirates of the Caribbean: The Curse of the Blac...  English     USA
# Harry Potter and the Deathly Hallows: Part I        English      UK
# The Hunger Games: Mockingjay - Part 1               English     USA
#
#                                                    content_rating  \
# movie_title
# Harry Potter and the Sorcerer's Stone                          PG
# R.I.P.D.                                                    PG-13
# Pirates of the Caribbean: The Curse of the Blac...          PG-13
# Harry Potter and the Deathly Hallows: Part I                  NaN
# The Hunger Games: Mockingjay - Part 1                       PG-13
#
#                                                          budget  title_year  \
# movie_title
# Harry Potter and the Sorcerer's Stone               125000000.0      2001.0
# R.I.P.D.                                            130000000.0      2013.0
# Pirates of the Caribbean: The Curse of the Blac...  140000000.0      2003.0
# Harry Potter and the Deathly Hallows: Part I                NaN      2010.0
# The Hunger Games: Mockingjay - Part 1               125000000.0      2014.0
#
#                                                     actor_2_facebook_likes  \
# movie_title
# Harry Potter and the Sorcerer's Stone                                687.0
# R.I.P.D.                                                           12000.0
# Pirates of the Caribbean: The Curse of the Blac...                  5000.0
# Harry Potter and the Deathly Hallows: Part I                        2000.0
# The Hunger Games: Mockingjay - Part 1                              22000.0
#
#                                                     imdb_score  aspect_ratio  \
# movie_title
# Harry Potter and the Sorcerer's Stone                      7.5          2.35
# R.I.P.D.                                                   5.6          2.35
# Pirates of the Caribbean: The Curse of the Blac...         8.1          2.35
# Harry Potter and the Deathly Hallows: Part I               6.4           NaN
# The Hunger Games: Mockingjay - Part 1                      6.7          2.35
#
#                                                     movie_facebook_likes
# movie_title
# Harry Potter and the Sorcerer's Stone                              16000
# R.I.P.D.                                                           20000
# Pirates of the Caribbean: The Curse of the Blac...                 10000
# Harry Potter and the Deathly Hallows: Part I                          25
# The Hunger Games: Mockingjay - Part 1                              52000

# %%
# slice to the end
movie.loc['The Hunger Games: Mockingjay - Part 1':].head()
# Out:
#                                        color     director_name  \
# movie_title
# The Hunger Games: Mockingjay - Part 1  Color  Francis Lawrence
# The Da Vinci Code                      Color        Ron Howard
# Rio 2                                  Color   Carlos Saldanha
# X-Men 2                                Color      Bryan Singer
# Fast Five                              Color        Justin Lin
#
#                                        num_critic_for_reviews  duration  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                   403.0     123.0
# The Da Vinci Code                                       294.0     174.0
# Rio 2                                                   159.0     101.0
# X-Men 2                                                 289.0     134.0
# Fast Five                                               342.0     132.0
#
#                                        director_facebook_likes  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                    508.0
# The Da Vinci Code                                       2000.0
# Rio 2                                                    107.0
# X-Men 2                                                    0.0
# Fast Five                                                681.0
#
#                                        actor_3_facebook_likes  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                 14000.0
# The Da Vinci Code                                       362.0
# Rio 2                                                    56.0
# X-Men 2                                                 346.0
# Fast Five                                             12000.0
#
#                                                  actor_2_name  \
# movie_title
# The Hunger Games: Mockingjay - Part 1  Philip Seymour Hoffman
# The Da Vinci Code                                  Seth Gabel
# Rio 2                                             Rachel Crow
# X-Men 2                                         Bruce Davison
# Fast Five                                          Vin Diesel
#
#                                        actor_1_facebook_likes        gross  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                 34000.0  337103873.0
# The Da Vinci Code                                     15000.0  217536138.0
# Rio 2                                                   688.0  131536019.0
# X-Men 2                                               20000.0  214948780.0
# Fast Five                                             23000.0  209805005.0
#
#                                                                           genres  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                  Adventure|Sci-Fi|Thriller
# The Da Vinci Code                                               Mystery|Thriller
# Rio 2                                  Adventure|Animation|Comedy|Family|Musical
# X-Men 2                                 Action|Adventure|Fantasy|Sci-Fi|Thriller
# Fast Five                                                  Action|Crime|Thriller
#
#                                             actor_1_name  num_voted_users  \
# movie_title
# The Hunger Games: Mockingjay - Part 1  Jennifer Lawrence           305008
# The Da Vinci Code                              Tom Hanks           314253
# Rio 2                                      Miguel Ferrer            58498
# X-Men 2                                     Hugh Jackman           405973
# Fast Five                                    Paul Walker           284792
#
#                                        cast_total_facebook_likes  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                      81385
# The Da Vinci Code                                          16008
# Rio 2                                                       1031
# X-Men 2                                                    20952
# Fast Five                                                  55345
#
#                                           actor_3_name  facenumber_in_poster  \
# movie_title
# The Hunger Games: Mockingjay - Part 1  Josh Hutcherson                   1.0
# The Da Vinci Code                      Jürgen Prochnow                   2.0
# Rio 2                                   Jeffrey Garcia                   0.0
# X-Men 2                                 Aaron Stanford                   4.0
# Fast Five                               Dwayne Johnson                   3.0
#
#                                                                            plot_keywords  \
# movie_title
# The Hunger Games: Mockingjay - Part 1  based on young adult novel|manipulation|rebell...
# The Da Vinci Code                      based on supposedly true story|holy grail|mary...
# Rio 2                                  amazon|bird|father in law|jungle|no opening cr...
# X-Men 2                                             mutant|prison|professor|school|x men
# Fast Five                                     drug lord|drugs|federal agent|heist|police
#
#                                                                          movie_imdb_link  \
# movie_title
# The Hunger Games: Mockingjay - Part 1  http://www.imdb.com/title/tt1951265/?ref_=fn_t...
# The Da Vinci Code                      http://www.imdb.com/title/tt0382625/?ref_=fn_t...
# Rio 2                                  http://www.imdb.com/title/tt2357291/?ref_=fn_t...
# X-Men 2                                http://www.imdb.com/title/tt0290334/?ref_=fn_t...
# Fast Five                              http://www.imdb.com/title/tt1596343/?ref_=fn_t...
#
#                                        num_user_for_reviews language country  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                 591.0  English     USA
# The Da Vinci Code                                    1966.0  English     USA
# Rio 2                                                  99.0  English     USA
# X-Men 2                                              1055.0  English  Canada
# Fast Five                                             366.0  English     USA
#
#                                       content_rating       budget  title_year  \
# movie_title
# The Hunger Games: Mockingjay - Part 1          PG-13  125000000.0      2014.0
# The Da Vinci Code                              PG-13  125000000.0      2006.0
# Rio 2                                              G  103000000.0      2014.0
# X-Men 2                                        PG-13  110000000.0      2003.0
# Fast Five                                      PG-13  125000000.0      2011.0
#
#                                        actor_2_facebook_likes  imdb_score  \
# movie_title
# The Hunger Games: Mockingjay - Part 1                 22000.0         6.7
# The Da Vinci Code                                       574.0         6.6
# Rio 2                                                   237.0         6.4
# X-Men 2                                                 505.0         7.5
# Fast Five                                             14000.0         7.3
#
#                                        aspect_ratio  movie_facebook_likes
# movie_title
# The Hunger Games: Mockingjay - Part 1          2.35                 52000
# The Da Vinci Code                              2.35                     0
# Rio 2                                          2.35                     0
# X-Men 2                                        2.35                     0
# Fast Five                                      2.35                 54000

# %% [markdown]
# #### Lists with .loc

# %%
movie_list = ['Fast Five', 'Avatar', 'My Big Fat Greek Wedding']
movie.loc[movie_list]
# Out:
#                           color  director_name  num_critic_for_reviews  \
# movie_title
# Fast Five                 Color     Justin Lin                   342.0
# Avatar                    Color  James Cameron                   723.0
# My Big Fat Greek Wedding  Color     Joel Zwick                   168.0
#
#                           duration  director_facebook_likes  \
# movie_title
# Fast Five                    132.0                    681.0
# Avatar                       178.0                      0.0
# My Big Fat Greek Wedding      95.0                     38.0
#
#                           actor_3_facebook_likes      actor_2_name  \
# movie_title
# Fast Five                                12000.0        Vin Diesel
# Avatar                                     855.0  Joel David Moore
# My Big Fat Greek Wedding                   249.0    Louis Mandylor
#
#                           actor_1_facebook_likes        gross  \
# movie_title
# Fast Five                                23000.0  209805005.0
# Avatar                                    1000.0  760505847.0
# My Big Fat Greek Wedding                   567.0  241437427.0
#
#                                                    genres  actor_1_name  \
# movie_title
# Fast Five                           Action|Crime|Thriller   Paul Walker
# Avatar                    Action|Adventure|Fantasy|Sci-Fi   CCH Pounder
# My Big Fat Greek Wedding            Comedy|Family|Romance  Nia Vardalos
#
#                           num_voted_users  cast_total_facebook_likes  \
# movie_title
# Fast Five                          284792                      55345
# Avatar                             886204                       4834
# My Big Fat Greek Wedding           102071                       1495
#
#                             actor_3_name  facenumber_in_poster  \
# movie_title
# Fast Five                 Dwayne Johnson                   3.0
# Avatar                         Wes Studi                   0.0
# My Big Fat Greek Wedding    Lainie Kazan                   3.0
#
#                                                               plot_keywords  \
# movie_title
# Fast Five                        drug lord|drugs|federal agent|heist|police
# Avatar                               avatar|future|marine|native|paraplegic
# My Big Fat Greek Wedding  baptism|greek|greek restaurant|prejudice|trave...
#
#                                                             movie_imdb_link  \
# movie_title
# Fast Five                 http://www.imdb.com/title/tt1596343/?ref_=fn_t...
# Avatar                    http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# My Big Fat Greek Wedding  http://www.imdb.com/title/tt0259446/?ref_=fn_t...
#
#                           num_user_for_reviews language country  \
# movie_title
# Fast Five                                366.0  English     USA
# Avatar                                  3054.0  English     USA
# My Big Fat Greek Wedding                 756.0  English     USA
#
#                          content_rating       budget  title_year  \
# movie_title
# Fast Five                         PG-13  125000000.0      2011.0
# Avatar                            PG-13  237000000.0      2009.0
# My Big Fat Greek Wedding             PG    5000000.0      2002.0
#
#                           actor_2_facebook_likes  imdb_score  aspect_ratio  \
# movie_title
# Fast Five                                14000.0         7.3          2.35
# Avatar                                     936.0         7.9          1.78
# My Big Fat Greek Wedding                   312.0         6.6          1.85
#
#                           movie_facebook_likes
# movie_title
# Fast Five                                54000
# Avatar                                   33000
# My Big Fat Greek Wedding                  5000

# %%
# single item list as a DataFrame and not a Series
movie.loc[['Avatar']]
# Out:
#              color  director_name  num_critic_for_reviews  duration  \
# movie_title
# Avatar       Color  James Cameron                   723.0     178.0
#
#              director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Avatar                           0.0                   855.0
#
#                  actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# Avatar       Joel David Moore                  1000.0  760505847.0
#
#                                       genres actor_1_name  num_voted_users  \
# movie_title
# Avatar       Action|Adventure|Fantasy|Sci-Fi  CCH Pounder           886204
#
#              cast_total_facebook_likes actor_3_name  facenumber_in_poster  \
# movie_title
# Avatar                            4834    Wes Studi                   0.0
#
#                                       plot_keywords  \
# movie_title
# Avatar       avatar|future|marine|native|paraplegic
#
#                                                movie_imdb_link  \
# movie_title
# Avatar       http://www.imdb.com/title/tt0499549/?ref_=fn_t...
#
#              num_user_for_reviews language country content_rating  \
# movie_title
# Avatar                     3054.0  English     USA          PG-13
#
#                   budget  title_year  actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar       237000000.0      2009.0                   936.0         7.9
#
#              aspect_ratio  movie_facebook_likes
# movie_title
# Avatar               1.78                 33000

# %% [markdown]
# ## Selecting columns with .iloc and .loc
# We can select columns through the .iloc and .loc indexers as well. Both these indexer use a **comma** to separate the row selection from the column selection. To do only column selection we use a **colon**, which selects all rows followed by a **comma** and then by the usual integer location or label selection.
#
# ### Select all rows with some columns using .iloc

# %%
# select all rows with column at the 5th position
movie.iloc[:, 5].head()
# Out:
# movie_title
# Avatar                                          855.0
# Pirates of the Caribbean: At World's End       1000.0
# Spectre                                         161.0
# The Dark Knight Rises                         23000.0
# Star Wars: Episode VII - The Force Awakens        NaN
# Name: actor_3_facebook_likes, dtype: float64

# %%
# select all rows with columns 3,6 and 10
movie.iloc[:, [3, 6, 10]].head()
# Out:
#                                             duration      actor_2_name  \
# movie_title
# Avatar                                         178.0  Joel David Moore
# Pirates of the Caribbean: At World's End       169.0     Orlando Bloom
# Spectre                                        148.0      Rory Kinnear
# The Dark Knight Rises                          164.0    Christian Bale
# Star Wars: Episode VII - The Force Awakens       NaN        Rob Walker
#
#                                                actor_1_name
# movie_title
# Avatar                                          CCH Pounder
# Pirates of the Caribbean: At World's End        Johnny Depp
# Spectre                                     Christoph Waltz
# The Dark Knight Rises                             Tom Hardy
# Star Wars: Episode VII - The Force Awakens      Doug Walker

# %%
# Select all the rows but slice the columns from 5 to 10
movie.iloc[:, 5:10].head()
# Out:
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary

# %% [markdown]
# ### Select all rows with some columns using .loc

# %%
movie.loc[:, 'director_name'].head()
# Out:
# movie_title
# Avatar                                            James Cameron
# Pirates of the Caribbean: At World's End         Gore Verbinski
# Spectre                                              Sam Mendes
# The Dark Knight Rises                         Christopher Nolan
# Star Wars: Episode VII - The Force Awakens          Doug Walker
# Name: director_name, dtype: object

# %%
movie.loc[:, ['director_name', 'actor_1_name', 'actor_2_name']].head()
# Out:
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                                actor_1_name      actor_2_name
# movie_title
# Avatar                                          CCH Pounder  Joel David Moore
# Pirates of the Caribbean: At World's End        Johnny Depp     Orlando Bloom
# Spectre                                     Christoph Waltz      Rory Kinnear
# The Dark Knight Rises                             Tom Hardy    Christian Bale
# Star Wars: Episode VII - The Force Awakens      Doug Walker        Rob Walker

# %%
# slice up to and including actor_1_name
movie.loc[:, :'actor_1_name'].head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                                actor_1_name
# movie_title
# Avatar                                          CCH Pounder
# Pirates of the Caribbean: At World's End        Johnny Depp
# Spectre                                     Christoph Waltz
# The Dark Knight Rises                             Tom Hardy
# Star Wars: Episode VII - The Force Awakens      Doug Walker

# %% [markdown]
# ## Selecting Rows and Columns simultaneously with .iloc and .loc
# Put selections both before and after the comma to select rows and columns

# %% [markdown]
# ### Selecting rows and columns simultaneously with .iloc

# %%
movie.iloc[4, 10]
# Out:
# 'Doug Walker'

# %%
movie.iloc[4:8, 10]
# Out:
# movie_title
# Star Wars: Episode VII - The Force Awakens     Doug Walker
# John Carter                                   Daryl Sabara
# Spider-Man 3                                  J.K. Simmons
# Tangled                                       Brad Garrett
# Name: actor_1_name, dtype: object

# %%
movie.iloc[4, 10:15]
# Out:
# actor_1_name                 Doug Walker
# num_voted_users                        8
# cast_total_facebook_likes            143
# actor_3_name                         NaN
# facenumber_in_poster                   0
# Name: Star Wars: Episode VII - The Force Awakens, dtype: object

# %%
movie.iloc[:4, 10:15]
# Out:
#                                              actor_1_name  num_voted_users  \
# movie_title
# Avatar                                        CCH Pounder           886204
# Pirates of the Caribbean: At World's End      Johnny Depp           471220
# Spectre                                   Christoph Waltz           275868
# The Dark Knight Rises                           Tom Hardy          1144337
#
#                                           cast_total_facebook_likes  \
# movie_title
# Avatar                                                         4834
# Pirates of the Caribbean: At World's End                      48350
# Spectre                                                       11700
# The Dark Knight Rises                                        106759
#
#                                                   actor_3_name  \
# movie_title
# Avatar                                               Wes Studi
# Pirates of the Caribbean: At World's End        Jack Davenport
# Spectre                                       Stephanie Sigman
# The Dark Knight Rises                     Joseph Gordon-Levitt
#
#                                           facenumber_in_poster
# movie_title
# Avatar                                                     0.0
# Pirates of the Caribbean: At World's End                   0.0
# Spectre                                                    1.0
# The Dark Knight Rises                                      0.0

# %%
movie.iloc[[1,100,50], [10, 5, 17]]
# Out:
#                                                actor_1_name  \
# movie_title
# Pirates of the Caribbean: At World's End        Johnny Depp
# The Fast and the Furious                        Paul Walker
# The Great Gatsby                          Leonardo DiCaprio
#
#                                           actor_3_facebook_likes  \
# movie_title
# Pirates of the Caribbean: At World's End                  1000.0
# The Fast and the Furious                                  4000.0
# The Great Gatsby                                            77.0
#
#                                           num_user_for_reviews
# movie_title
# Pirates of the Caribbean: At World's End                1238.0
# The Fast and the Furious                                 988.0
# The Great Gatsby                                         753.0

# %%
movie.iloc[[2], 6:10]
# Out:
#              actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# Spectre      Rory Kinnear                 11000.0  200074175.0
#
#                                 genres
# movie_title
# Spectre      Action|Adventure|Thriller

# %% [markdown]
# ### Selecting rows and columns with .loc

# %%
movie.loc['My Big Fat Greek Wedding', 'director_name']
# Out:
# 'Joel Zwick'

# %%
movie_list = ['The Rock', 'Spider-Man']
col_list = ['director_name', 'title_year']
movie.loc[movie_list, col_list]
# Out:
#             director_name  title_year
# movie_title
# The Rock      Michael Bay      1996.0
# Spider-Man      Sam Raimi      2002.0

# %%
movie.loc[:'The Rock':100, 'duration']
# Out:
# movie_title
# Avatar                                   178.0
# The Fast and the Furious                 106.0
# Harry Potter and the Sorcerer's Stone    159.0
# Epic                                     102.0
# 102 Dalmatians                           100.0
# Pompeii                                  105.0
# Name: duration, dtype: float64

# %%
movie.loc[movie_list, 'duration':]
# Out:
#              duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# The Rock        136.0                      0.0                   904.0
# Spider-Man      121.0                      0.0                  4000.0
#
#               actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# The Rock     Michael Biehn                 12000.0  134006721.0
# Spider-Man    James Franco                 24000.0  403706375.0
#
#                                        genres  actor_1_name  num_voted_users  \
# movie_title
# The Rock            Action|Adventure|Thriller  Nicolas Cage           259492
# Spider-Man   Action|Adventure|Fantasy|Romance  J.K. Simmons           544665
#
#              cast_total_facebook_likes     actor_3_name  facenumber_in_poster  \
# movie_title
# The Rock                         15999  Bokeem Woodbine                   1.0
# Spider-Man                       40484    Kirsten Dunst                   0.0
#
#                                        plot_keywords  \
# movie_title
# The Rock         alcatraz|fbi|general|hostage|rocket
# Spider-Man   evil|goblin|spider|spider man|superhero
#
#                                                movie_imdb_link  \
# movie_title
# The Rock     http://www.imdb.com/title/tt0117500/?ref_=fn_t...
# Spider-Man   http://www.imdb.com/title/tt0145487/?ref_=fn_t...
#
#              num_user_for_reviews language country content_rating  \
# movie_title
# The Rock                    415.0  English     USA              R
# Spider-Man                 2012.0  English     USA          PG-13
#
#                   budget  title_year  actor_2_facebook_likes  imdb_score  \
# movie_title
# The Rock      75000000.0      1996.0                  2000.0         7.4
# Spider-Man   139000000.0      2002.0                 11000.0         7.3
#
#              aspect_ratio  movie_facebook_likes
# movie_title
# The Rock             2.35                 51000
# Spider-Man           1.85                  5000

# %% [markdown]
# ## Selections to Avoid
# It was written earlier that only column names go inside of brackets for DataFrames. This isn't entirely true. It is possible to pass a slice to the brackets to return rows. I would highly recommend against doing this and use brackets only for column names, **.loc** for index labeled based selection and **.iloc** for integer position selection.

# %%
# select the first 5 rows with brackets - bad idea!
movie[:5]
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                                actor_1_name  num_voted_users  \
# movie_title
# Avatar                                          CCH Pounder           886204
# Pirates of the Caribbean: At World's End        Johnny Depp           471220
# Spectre                                     Christoph Waltz           275868
# The Dark Knight Rises                             Tom Hardy          1144337
# Star Wars: Episode VII - The Force Awakens      Doug Walker                8
#
#                                             cast_total_facebook_likes  \
# movie_title
# Avatar                                                           4834
# Pirates of the Caribbean: At World's End                        48350
# Spectre                                                         11700
# The Dark Knight Rises                                          106759
# Star Wars: Episode VII - The Force Awakens                        143
#
#                                                     actor_3_name  \
# movie_title
# Avatar                                                 Wes Studi
# Pirates of the Caribbean: At World's End          Jack Davenport
# Spectre                                         Stephanie Sigman
# The Dark Knight Rises                       Joseph Gordon-Levitt
# Star Wars: Episode VII - The Force Awakens                   NaN
#
#                                             facenumber_in_poster  \
# movie_title
# Avatar                                                       0.0
# Pirates of the Caribbean: At World's End                     0.0
# Spectre                                                      1.0
# The Dark Knight Rises                                        0.0
# Star Wars: Episode VII - The Force Awakens                   0.0
#
#                                                                                 plot_keywords  \
# movie_title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End    goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                   bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                       deception|imprisonment|lawlessness|police offi...
# Star Wars: Episode VII - The Force Awakens                                                NaN
#
#                                                                               movie_imdb_link  \
# movie_title
# Avatar                                      http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# Pirates of the Caribbean: At World's End    http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# Spectre                                     http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# The Dark Knight Rises                       http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# Star Wars: Episode VII - The Force Awakens  http://www.imdb.com/title/tt5289954/?ref_=fn_t...
#
#                                             num_user_for_reviews language  \
# movie_title
# Avatar                                                    3054.0  English
# Pirates of the Caribbean: At World's End                  1238.0  English
# Spectre                                                    994.0  English
# The Dark Knight Rises                                     2701.0  English
# Star Wars: Episode VII - The Force Awakens                   NaN      NaN
#
#                                            country content_rating  \
# movie_title
# Avatar                                         USA          PG-13
# Pirates of the Caribbean: At World's End       USA          PG-13
# Spectre                                         UK          PG-13
# The Dark Knight Rises                          USA          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN            NaN
#
#                                                  budget  title_year  \
# movie_title
# Avatar                                      237000000.0      2009.0
# Pirates of the Caribbean: At World's End    300000000.0      2007.0
# Spectre                                     245000000.0      2015.0
# The Dark Knight Rises                       250000000.0      2012.0
# Star Wars: Episode VII - The Force Awakens          NaN         NaN
#
#                                             actor_2_facebook_likes  \
# movie_title
# Avatar                                                       936.0
# Pirates of the Caribbean: At World's End                    5000.0
# Spectre                                                      393.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                    12.0
#
#                                             imdb_score  aspect_ratio  \
# movie_title
# Avatar                                             7.9          1.78
# Pirates of the Caribbean: At World's End           7.1          2.35
# Spectre                                            6.8          2.35
# The Dark Knight Rises                              8.5          2.35
# Star Wars: Episode VII - The Force Awakens         7.1           NaN
#
#                                             movie_facebook_likes
# movie_title
# Avatar                                                     33000
# Pirates of the Caribbean: At World's End                       0
# Spectre                                                    85000
# The Dark Knight Rises                                     164000
# Star Wars: Episode VII - The Force Awakens                     0

# %% [markdown]
# ### Using **`.ix`** to mix both integer and label indexing (THIS IS DEPRECATED: DO NOT USE)
# The **`.ix`** operator provided some flexibility to select by both integer position and index label simultaneously. This was a bad idea and it has been deprecated. You will still see it used online especially on stackoverflow. Do not be tempted to use it!

# %% [markdown]
# ### Selecting single elements with `.at` and `.iat`
# In the rare case that you would like to select exactly one cell of data, you can use **`.at`** for label based selection and **`.iat`** for integer based selection. They work analogously to **`.loc`** and **`.iloc`** and don't provide any extra functionality just are faster. Technically, a single element is called a **scalar** value.

# %%
movie.iat[5, 10]
# Out:
# 'Daryl Sabara'

# %%
movie.at['My Big Fat Greek Wedding', 'actor_1_name']
# Out:
# 'Nia Vardalos'

# %% [markdown]
# # Your Turn
#
# ### Begin by running the code below
# This ensures that you are using the correct data.

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">Use the **`describe`** method on the movie dataset and include only the object columns. Transpose the output.</span>

# %%
# your code here

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Use the **`type`** function to output the object type for both the index and the columns.</span>

# %%
# your code here

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Select all three actor name columns.</span>

# %%
# your code here

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Select the content rating column as a Series and then as a DataFrame</span>

# %%
# your code here

# %% [markdown]
# ### Problem 5
# <span  style="color:green; font-size:16px">Select the 3rd and 5th rows from the movie dataset</span>

# %%
# your code here

# %% [markdown]
# ### Problem 6
# <span  style="color:green; font-size:16px">Select the 3rd and 5th columns from the movie dataset</span>

# %%
# your code here

# %% [markdown]
# ### Problem 7
# <span  style="color:green; font-size:16px">Select the first 5 rows and the last 5 columns</span>

# %%
# your code here

# %% [markdown]
# ### Problem 8
# <span  style="color:green; font-size:16px">Select the movie 'The Dark Night Rises'</span>

# %%
# your code here

# %% [markdown]
# ### Problem 9
# <span  style="color:green; font-size:16px">The values of the index are stored in a numpy array. Numpy arrays use only integer location for selection. Output the movie title from 50 to 100 using the values of the index. </span>

# %%
# your code here

# %% [markdown]
# ### Problem 10
# <span  style="color:green; font-size:16px">Select the first 3 rows and 3 columns using **`.loc`**</span>

# %%
# your code here

# %% [markdown]
# ### Problem 11
# <span  style="color:green; font-size:16px">Select a single scalar value using **`.loc`** and then do the same things with **`.at`** and use %timeit to see the speed difference.</span>

# %%
# your code here
